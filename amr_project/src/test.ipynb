# %%
import cv2
import os
import glob

base_dir = "/home/dw/ws_job_msislab/amr_project/data/video_data/20251217_video_2"

# 최상위 images 폴더 생성
root_output_dir = os.path.join(base_dir, "images")
os.makedirs(root_output_dir, exist_ok=True)

# MP4 파일 리스트 가져오기
video_list = sorted(glob.glob(os.path.join(base_dir, "color_output_*.mp4")))

print(f"[INFO] 감지된 MP4 파일 수: {len(video_list)}")

for video_path in video_list:
    video_name = os.path.basename(video_path).replace(".mp4", "")
    print(f"\n[START] {video_name} 변환 시작")

    # 영상별 폴더 생성
    output_dir = os.path.join(root_output_dir, video_name)
    os.makedirs(output_dir, exist_ok=True)

    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"[ERROR] 비디오 열기 실패: {video_path}")
        continue

    frame_idx = 1  # 영상마다 1부터 시작

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        prefix = "20251216"
        save_name = f"{prefix}_{video_name}_{frame_idx:06d}.jpg"
        save_path = os.path.join(output_dir, save_name)
        cv2.imwrite(save_path, frame)

        frame_idx += 1

        if frame_idx % 500 == 0:
            print(f"[INFO] {video_name}: {frame_idx}장 저장 중…")

    cap.release()
    print(f"[DONE] {video_name}: 총 {frame_idx-1}장 저장")

print("\n[ALL DONE] 모든 MP4 변환 완료!")

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# 여러 원본 폴더들
origin_bases = [
    "/home/dw/ws_job_msislab/amr_project/data/image_data/for_yolo_cls/20251216_2",
    "/home/dw/ws_job_msislab/amr_project/data/image_data/for_yolo_cls/20251217",
    "/home/dw/ws_job_msislab/amr_project/data/image_data/for_yolo_cls/20251217_2",
]

target_base = "/home/dw/ws_job_msislab/amr_project/for_training/20251217_2"

train_dir = os.path.join(target_base, "train")
val_dir = os.path.join(target_base, "val")

# 기존 결과 삭제 후 다시 생성
shutil.rmtree(target_base, ignore_errors=True)
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)

classes = ["box_0", "box_1", "box_2", "box_3", "box_4", "unknown"]
IMG_EXTS = (".jpg", ".jpeg", ".png")

TEST_SIZE = 0.15
RANDOM_STATE = 25

def copy_with_prefix(src_path: str, dst_folder: str, prefix: str):
    """
    폴더명 prefix 붙여 저장해서 충돌 방지 + 출처 추적 가능
    """
    base = os.path.basename(src_path)
    name, ext = os.path.splitext(base)
    out_name = f"{prefix}__{name}{ext}"
    dst_path = os.path.join(dst_folder, out_name)

    # 혹시 같은 파일이 또 있으면 _1, _2 붙이기
    if not os.path.exists(dst_path):
        shutil.copy2(src_path, dst_path)
        return

    i = 1
    while True:
        out_name2 = f"{prefix}__{name}_{i}{ext}"
        dst_path2 = os.path.join(dst_folder, out_name2)
        if not os.path.exists(dst_path2):
            shutil.copy2(src_path, dst_path2)
            return
        i += 1


# 클래스별 전체 누적 카운트용
total_train = {c: 0 for c in classes}
total_val = {c: 0 for c in classes}

for origin_base in origin_bases:
    folder_tag = os.path.basename(origin_base.rstrip("/"))

    print(f"\n========== [ORIGIN] {origin_base} (tag={folder_tag}) ==========")

    for cls in classes:
        src_folder = os.path.join(origin_base, cls)

        if not os.path.isdir(src_folder):
            print(f"[WARN] 폴더 없음: {src_folder} (skip)")
            continue

        images = [
            os.path.join(src_folder, f)
            for f in os.listdir(src_folder)
            if f.lower().endswith(IMG_EXTS)
        ]

        print(f"[INFO] {folder_tag}/{cls}: 총 {len(images)}장")

        if len(images) == 0:
            continue

        # 너무 적으면 val이 0장이 될 수 있으니 예외 처리
        if len(images) < 2:
            train_imgs, val_imgs = images, []
        else:
            # 폴더별(=origin_base별) 85/15 유지 split
            train_imgs, val_imgs = train_test_split(
                images,
                test_size=TEST_SIZE,
                random_state=RANDOM_STATE,
                shuffle=True
            )

        train_cls_dir = os.path.join(train_dir, cls)
        val_cls_dir = os.path.join(val_dir, cls)
        os.makedirs(train_cls_dir, exist_ok=True)
        os.makedirs(val_cls_dir, exist_ok=True)

        for img in train_imgs:
            copy_with_prefix(img, train_cls_dir, prefix=folder_tag)
        for img in val_imgs:
            copy_with_prefix(img, val_cls_dir, prefix=folder_tag)

        total_train[cls] += len(train_imgs)
        total_val[cls] += len(val_imgs)

        print(f"[DONE] {folder_tag}/{cls} → train {len(train_imgs)}, val {len(val_imgs)}")

print("\n========== [SUMMARY] 전체 누적 ==========")
for cls in classes:
    print(f"{cls:10s} | train {total_train[cls]:6d} | val {total_val[cls]:6d}")

print("\n[ALL DONE] 폴더별 비율 유지(각 폴더 85/15) 후 합쳐서 완료!")

# %%
from ultralytics import YOLO

# -------------------------------------------------
# 모델 로드 (classification)
# -------------------------------------------------
model = YOLO("yolo11s-cls.pt")

data_path = "/home/dw/ws_job_msislab/amr_project/for_training/20251217_2"

# -------------------------------------------------
# 학습
# -------------------------------------------------
model.train(
    data=data_path,
    epochs=500,
    imgsz=224,
    batch=32,
    patience=25,
    save=True,
    save_period=0,
    seed=25,
    deterministic=True,

    optimizer="AdamW",
    lr0=1e-3,
    lrf=1e-2,
    weight_decay=5e-4,
    momentum=0.9,

    cos_lr=True,
    warmup_epochs=3,
    warmup_momentum=0.8,
    warmup_bias_lr=0.1,

    hsv_h=0.015,
    hsv_s=0.4,
    hsv_v=0.4,
    degrees=5.0,
    translate=0.05,
    scale=0.2,
    shear=0.0,
    flipud=0.0,
    fliplr=0.5,
    mosaic=0.0,
    mixup=0.1,
    copy_paste=0.0,

    erasing=0.0,          # ✅ Random Erasing(검은 네모) 끄기

    label_smoothing=0.05,
    dropout=0.2,

    val=True,
    split="val",
    save_json=False,

    device=0,
    workers=8,
    amp=True,
    cache=False,
    verbose=True,
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.239 available 😃 Update with 'pip install -U ultralytics'
# WARNING ⚠️ 'label_smoothing' is deprecated and will be removed in the future.
# Ultralytics 8.3.202 🚀 Python-3.10.12 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 7932MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/home/dw/ws_job_msislab/amr_project/for_training/20251217_2, degrees=5.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.2, dynamic=False, embed=None, epochs=500, erasing=0.0, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.4, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.1, mode=train, model=yolo11s-cls.pt, momentum=0.9, mosaic=0.0, multi_scale=False, name=train13, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=25, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/dw/ws_job_msislab/amr_project/src/runs/classify/train13, save_frames=False, save_json=False, save_period=0, save_txt=False, scale=0.2, seed=25, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.05, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /home/dw/ws_job_msislab/amr_project/for_training/20251217_2/train... found 5025 images in 6 classes ✅
# val: /home/dw/ws_job_msislab/amr_project/for_training/20251217_2/val... found 896 images in 6 classes ✅
# test: None...
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    665606  ultralytics.nn.modules.head.Classify         [512, 6]
# YOLO11s-cls summary: 86 layers, 5,450,694 parameters, 5,450,694 gradients, 12.1 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5243.6±1362.8 MB/s, size: 107.4 KB)
# train: Scanning /home/dw/ws_job_msislab/amr_project/for_training/20251217_2/train... 5025 images, 0 corrupt: 100% ━━━━━━━━━━━━ 5025/5025 12.0Mit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 
6s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 53.1it/s 0.3s0.1s
#                    all      0.988          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      65/500      1.04G    0.04718          1        224: 100% ━━━━━━━━━━━━ 158/158 24.5it/s 6.4s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 37.9it/s 0.4s0.2s
#                    all       0.99          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      66/500      1.04G     0.0543          1        224: 100% ━━━━━━━━━━━━ 158/158 24.3it/s 6.5s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 44.4it/s 0.3s0.2s
#                    all      0.985          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      67/500      1.04G    0.02396          1        224: 100% ━━━━━━━━━━━━ 158/158 24.2it/s 6.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 48.8it/s 0.3s0.1s
#                    all      0.987          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      68/500      1.04G    0.01883          1        224: 100% ━━━━━━━━━━━━ 158/158 25.3it/s 6.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 54.3it/s 0.3s0.1s
#                    all      0.994          1
# EarlyStopping: Training stopped early as no improvement observed in last 25 epochs. Best results observed at epoch 43, best model saved as best.pt.
# To update EarlyStopping(patience=25) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 68 epochs completed in 0.134 hours.
# Optimizer stripped from /home/dw/ws_job_msislab/amr_project/src/runs/classify/train13/weights/last.pt, 11.0MB
# Optimizer stripped from /home/dw/ws_job_msislab/amr_project/src/runs/classify/train13/weights/best.pt, 11.0MB
#
# Validating /home/dw/ws_job_msislab/amr_project/src/runs/classify/train13/weights/best.pt...
# Ultralytics 8.3.202 🚀 Python-3.10.12 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 7932MiB)
# YOLO11s-cls summary (fused): 47 layers, 5,441,814 parameters, 0 gradients, 12.0 GFLOPs
# train: /home/dw/ws_job_msislab/amr_project/for_training/20251217_2/train... found 5025 images in 6 classes ✅
# val: /home/dw/ws_job_msislab/amr_project/for_training/20251217_2/val... found 896 images in 6 classes ✅
# test: None...
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 35.0it/s 0.4s0.1s
#                    all      0.997          1
# Speed: 0.1ms preprocess, 0.3ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /home/dw/ws_job_msislab/amr_project/src/runs/classify/train13
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7ce73c32cf40>
# curves: []
# curves_results: []
# fitness: 0.9983258843421936
# keys: ['metrics/accuracy_top1', 'metrics/accuracy_top5']
# results_dict: {'metrics/accuracy_top1': 0.9966517686843872, 'metrics/accuracy_top5': 1.0, 'fitness': 0.9983258843421936}
# save_dir: PosixPath('/home/dw/ws_job_msislab/amr_project/src/runs/classify/train13')
# speed: {'preprocess': 0.07965046093261208, 'inference': 0.31150509375420044, 'loss': 0.00017972433040215816, 'postprocess': 0.0003557812472568652}
# task: 'classify'
# top1: 0.9966517686843872
# top5: 1.0

# %% [markdown]
# ### obb

# %%
import os
import shutil

# =========================
# 경로 설정
# =========================
SRC_DIRS = [
    "/home/dw/ws_job_msislab/amr_project/data/image_data/for_yolo_obj/20251210",
    "/home/dw/ws_job_msislab/amr_project/data/image_data/for_yolo_obj/20251218",
]

DST_DIR = "/home/dw/ws_job_msislab/amr_project/for_training/20251218_obb"

# =========================
# 실행
# =========================
os.makedirs(DST_DIR, exist_ok=True)

copied = 0
skipped = 0

for src in SRC_DIRS:
    files = os.listdir(src)

    for fname in files:
        if not (fname.endswith(".jpg") or fname.endswith(".json")):
            continue

        src_path = os.path.join(src, fname)
        dst_path = os.path.join(DST_DIR, fname)

        if os.path.exists(dst_path):
            skipped += 1
            continue

        shutil.copy(src_path, dst_path)
        copied += 1

print("===================================")
print(f"✅ 복사 완료")
print(f" - 복사된 파일 : {copied}")
print(f" - 이미 존재해서 스킵 : {skipped}")
print(f" - 대상 폴더 : {DST_DIR}")
print("===================================")
# Out:
# ===================================
# ✅ 복사 완료
#  - 복사된 파일 : 304
#  - 이미 존재해서 스킵 : 0
#  - 대상 폴더 : /home/dw/ws_job_msislab/amr_project/for_training/20251218_obb
# ===================================

# %%
import json
import glob
import os

# 검사할 폴더
DIR = "/home/dw/ws_job_msislab/amr_project/for_training/20251218_obb"

# 폴더 내 모든 JSON 파일 로드
json_files = sorted(glob.glob(os.path.join(DIR, "*.json")))

print(f"\n===== Polygon 점 개수 검사 (YOLO-OBB용) =====\n")
print(f"총 JSON 파일: {len(json_files)}개\n")

if not json_files:
    print("❌ JSON 파일이 없습니다.")
    exit()

for json_path in json_files:
    print(f"\n📌 파일: {os.path.basename(json_path)}")

    try:
        with open(json_path, "r") as f:
            data = json.load(f)
    except Exception as e:
        print(f"   ❌ JSON 파일 열기 실패: {e}")
        continue

    shapes = data.get("shapes", [])

    if not shapes:
        print("   ❌ shapes 없음 (라벨링 데이터 없음)")
        continue

    for idx, s in enumerate(shapes):
        if s.get("shape_type") != "polygon":
            print(f"   [{idx}] ❌ polygon 아님 → {s.get('shape_type')}")
            continue

        pts = s.get("points", [])
        n = len(pts)

        if n == 4:
            print(f"   [{idx}] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)")
        else:
            print(f"   [{idx}] ❌ {n}점 polygon → YOLO-OBB 불가 (반드시 4점 필요)")
# Out:
# ===== Polygon 점 개수 검사 (YOLO-OBB용) =====
#
# 총 JSON 파일: 127개
#
#
# 📌 파일: color_output_1_000370.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000377.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000499.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000658.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000661.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000668.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000671.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000673.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000677.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000685.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000693.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000697.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000700.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000704.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000708.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000715.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000718.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000721.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000725.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000726.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000729.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000745.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000772.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000894.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_000976.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001090.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001105.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001108.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001111.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001114.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001115.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001117.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001118.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001132.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001157.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001165.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001183.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001196.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001259.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001280.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001351.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001352.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001353.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001358.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001407.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001410.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001428.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001432.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001491.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001510.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001511.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001512.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001518.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001545.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001575.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001620.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001626.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001629.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001636.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001823.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001875.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001898.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001902.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001915.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001923.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001930.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001957.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_001960.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_002007.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_002012.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_002042.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_002403.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_002417.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_002600.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_002604.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_002608.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_002618.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_002633.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_002635.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_002925.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_003335.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_003342.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_003413.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_003414.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_003431.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_003438.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_003439.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_003445.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_003461.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_003464.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_003513.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_1_003548.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [3] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_2_000054.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_2_000310.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_2_000313.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_2_000633.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_2_000636.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_2_000656.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_2_000730.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: color_output_2_000746.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [1] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#    [2] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_000210.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_000220.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_000250.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_000310.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_000540.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_000590.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_000730.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_000810.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_000840.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_1000210.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_1000220.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_1000250.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_1000310.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_1000540.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_1000590.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_1000730.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_1000810.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_1000840.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_2000210.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_2000220.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_2000250.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_2000310.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_2000540.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_2000590.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_2000730.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_2000810.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)
#
# 📌 파일: frame_2000840.json
#    [0] ✔ OK: 4점 polygon (YOLO-OBB 학습 가능)

# %%
import json
import os
from glob import glob
import numpy as np

# 변환할 폴더
BASE = "/home/dw/ws_job_msislab/amr_project/for_training/20251218_obb"

json_files = sorted(glob(os.path.join(BASE, "*.json")))

print("\n===== JSON → YOLO11-OBB 변환 시작 =====\n")


def sort_polygon_points(pts):
    """
    4개 점을 중심 기준으로 시계/반시계 순서로 정렬.
    YOLO OBB 학습을 위한 필수 단계.
    """

    pts = np.array(pts)

    # 중심점
    cx = np.mean(pts[:, 0])
    cy = np.mean(pts[:, 1])

    # 각도 계산
    angles = np.arctan2(pts[:, 1] - cy, pts[:, 0] - cx)

    # 각도 기준 정렬 (반시계 방향)
    sorted_idx = np.argsort(angles)

    return pts[sorted_idx].tolist()



for json_path in json_files:
    with open(json_path, "r") as f:
        data = json.load(f)

    img_w = data["imageWidth"]
    img_h = data["imageHeight"]

    shapes = data.get("shapes", [])

    # 출력 txt 경로
    txt_path = json_path.replace(".json", ".txt")
    lines = []

    for s in shapes:
        if s.get("shape_type") != "polygon":
            continue

        pts = s.get("points", [])

        if len(pts) != 4:
            print(f"❌ {json_path} — polygon 점 {len(pts)}개 → 4점 필수")
            continue

        # 점 순서 정렬
        pts_sorted = sort_polygon_points(pts)

        # YOLO 정규화 좌표
        yolo_pts = []
        for (x, y) in pts_sorted:
            yolo_pts.append(x / img_w)
            yolo_pts.append(y / img_h)

        # class_id = 0
        line = "0 " + " ".join([f"{v:.6f}" for v in yolo_pts])
        lines.append(line)

    # txt 파일 저장
    with open(txt_path, "w") as f:
        for line in lines:
            f.write(line + "\n")

    print(f"[OK] {os.path.basename(txt_path)} 생성됨")

print("\n===== 변환 완료 =====\n")
# Out:
# ===== JSON → YOLO11-OBB 변환 시작 =====
#
# [OK] color_output_1_000370.txt 생성됨
# [OK] color_output_1_000377.txt 생성됨
# [OK] color_output_1_000499.txt 생성됨
# [OK] color_output_1_000658.txt 생성됨
# [OK] color_output_1_000661.txt 생성됨
# [OK] color_output_1_000668.txt 생성됨
# [OK] color_output_1_000671.txt 생성됨
# [OK] color_output_1_000673.txt 생성됨
# [OK] color_output_1_000677.txt 생성됨
# [OK] color_output_1_000685.txt 생성됨
# [OK] color_output_1_000693.txt 생성됨
# [OK] color_output_1_000697.txt 생성됨
# [OK] color_output_1_000700.txt 생성됨
# [OK] color_output_1_000704.txt 생성됨
# [OK] color_output_1_000708.txt 생성됨
# [OK] color_output_1_000715.txt 생성됨
# [OK] color_output_1_000718.txt 생성됨
# [OK] color_output_1_000721.txt 생성됨
# [OK] color_output_1_000725.txt 생성됨
# [OK] color_output_1_000726.txt 생성됨
# [OK] color_output_1_000729.txt 생성됨
# [OK] color_output_1_000745.txt 생성됨
# [OK] color_output_1_000772.txt 생성됨
# [OK] color_output_1_000894.txt 생성됨
# [OK] color_output_1_000976.txt 생성됨
# [OK] color_output_1_001090.txt 생성됨
# [OK] color_output_1_001105.txt 생성됨
# [OK] color_output_1_001108.txt 생성됨
# [OK] color_output_1_001111.txt 생성됨
# [OK] color_output_1_001114.txt 생성됨
# [OK] color_output_1_001115.txt 생성됨
# [OK] color_output_1_001117.txt 생성됨
# [OK] color_output_1_001118.txt 생성됨
# [OK] color_output_1_001132.txt 생성됨
# [OK] color_output_1_001157.txt 생성됨
# [OK] color_output_1_001165.txt 생성됨
# [OK] color_output_1_001183.txt 생성됨
# [OK] color_output_1_001196.txt 생성됨
# [OK] color_output_1_001259.txt 생성됨
# [OK] color_output_1_001280.txt 생성됨
# [OK] color_output_1_001351.txt 생성됨
# [OK] color_output_1_001352.txt 생성됨
# [OK] color_output_1_001353.txt 생성됨
# [OK] color_output_1_001358.txt 생성됨
# [OK] color_output_1_001407.txt 생성됨
# [OK] color_output_1_001410.txt 생성됨
# [OK] color_output_1_001428.txt 생성됨
# [OK] color_output_1_001432.txt 생성됨
# [OK] color_output_1_001491.txt 생성됨
# [OK] color_output_1_001510.txt 생성됨
# [OK] color_output_1_001511.txt 생성됨
# [OK] color_output_1_001512.txt 생성됨
# [OK] color_output_1_001518.txt 생성됨
# [OK] color_output_1_001545.txt 생성됨
# [OK] color_output_1_001575.txt 생성됨
# [OK] color_output_1_001620.txt 생성됨
# [OK] color_output_1_001626.txt 생성됨
# [OK] color_output_1_001629.txt 생성됨
# [OK] color_output_1_001636.txt 생성됨
# [OK] color_output_1_001823.txt 생성됨
# [OK] color_output_1_001875.txt 생성됨
# [OK] color_output_1_001898.txt 생성됨
# [OK] color_output_1_001902.txt 생성됨
# [OK] color_output_1_001915.txt 생성됨
# [OK] color_output_1_001923.txt 생성됨
# [OK] color_output_1_001930.txt 생성됨
# [OK] color_output_1_001957.txt 생성됨
# [OK] color_output_1_001960.txt 생성됨
# [OK] color_output_1_002007.txt 생성됨
# [OK] color_output_1_002012.txt 생성됨
# [OK] color_output_1_002042.txt 생성됨
# [OK] color_output_1_002403.txt 생성됨
# [OK] color_output_1_002417.txt 생성됨
# [OK] color_output_1_002600.txt 생성됨
# [OK] color_output_1_002604.txt 생성됨
# [OK] color_output_1_002608.txt 생성됨
# [OK] color_output_1_002618.txt 생성됨
# [OK] color_output_1_002633.txt 생성됨
# [OK] color_output_1_002635.txt 생성됨
# [OK] color_output_1_002925.txt 생성됨
# [OK] color_output_1_003335.txt 생성됨
# [OK] color_output_1_003342.txt 생성됨
# [OK] color_output_1_003413.txt 생성됨
# [OK] color_output_1_003414.txt 생성됨
# [OK] color_output_1_003431.txt 생성됨
# [OK] color_output_1_003438.txt 생성됨
# [OK] color_output_1_003439.txt 생성됨
# [OK] color_output_1_003445.txt 생성됨
# [OK] color_output_1_003461.txt 생성됨
# [OK] color_output_1_003464.txt 생성됨
# [OK] color_output_1_003513.txt 생성됨
# [OK] color_output_1_003548.txt 생성됨
# [OK] color_output_2_000054.txt 생성됨
# [OK] color_output_2_000310.txt 생성됨
# [OK] color_output_2_000313.txt 생성됨
# [OK] color_output_2_000633.txt 생성됨
# [OK] color_output_2_000636.txt 생성됨
# [OK] color_output_2_000656.txt 생성됨
# [OK] color_output_2_000730.txt 생성됨
# [OK] color_output_2_000746.txt 생성됨
# [OK] frame_000210.txt 생성됨
# [OK] frame_000220.txt 생성됨
# [OK] frame_000250.txt 생성됨
# [OK] frame_000310.txt 생성됨
# [OK] frame_000540.txt 생성됨
# [OK] frame_000590.txt 생성됨
# [OK] frame_000730.txt 생성됨
# [OK] frame_000810.txt 생성됨
# [OK] frame_000840.txt 생성됨
# [OK] frame_1000210.txt 생성됨
# [OK] frame_1000220.txt 생성됨
# [OK] frame_1000250.txt 생성됨
# [OK] frame_1000310.txt 생성됨
# [OK] frame_1000540.txt 생성됨
# [OK] frame_1000590.txt 생성됨
# [OK] frame_1000730.txt 생성됨
# [OK] frame_1000810.txt 생성됨
# [OK] frame_1000840.txt 생성됨
# [OK] frame_2000210.txt 생성됨
# [OK] frame_2000220.txt 생성됨
# [OK] frame_2000250.txt 생성됨
# [OK] frame_2000310.txt 생성됨
# [OK] frame_2000540.txt 생성됨
# [OK] frame_2000590.txt 생성됨
# [OK] frame_2000730.txt 생성됨
# [OK] frame_2000810.txt 생성됨
# [OK] frame_2000840.txt 생성됨
#
# ===== 변환 완료 =====

# %%
import os
import shutil
from glob import glob
import random
import yaml

BASE = "/home/dw/ws_job_msislab/amr_project/for_training/20251218_obb"

# 1) train/val/images/labels 디렉토리 생성
train_img_dir = os.path.join(BASE, "train/images")
train_lbl_dir = os.path.join(BASE, "train/labels")
val_img_dir   = os.path.join(BASE, "val/images")
val_lbl_dir   = os.path.join(BASE, "val/labels")

for d in [train_img_dir, train_lbl_dir, val_img_dir, val_lbl_dir]:
    os.makedirs(d, exist_ok=True)


print("\n===== Step 1: JSON 파일 삭제 =====")
json_files = glob(os.path.join(BASE, "*.json"))
for jf in json_files:
    os.remove(jf)
    print(f"삭제됨 → {os.path.basename(jf)}")


print("\n===== Step 2: 이미지 + 라벨 파일 수집 =====")
images = sorted(glob(os.path.join(BASE, "*.jpg")))
labels = sorted(glob(os.path.join(BASE, "*.txt")))

print(f"이미지: {len(images)}개")
print(f"라벨: {len(labels)}개")

assert len(images) == len(labels), "\n❌ 이미지/라벨 개수가 다릅니다!"


# 이미지/라벨 쌍으로 묶기
pairs = list(zip(images, labels))
random.shuffle(pairs)

val_ratio = 0.2
val_count = int(len(pairs) * val_ratio)

val_set = pairs[:val_count]
train_set = pairs[val_count:]

print(f"Train: {len(train_set)}개")
print(f"Val:   {len(val_set)}개")


def move_pairs(pairs, img_dest, lbl_dest):
    for img, lbl in pairs:
        # 파일 이동 (복사 X)
        shutil.move(img, os.path.join(img_dest, os.path.basename(img)))
        shutil.move(lbl, os.path.join(lbl_dest, os.path.basename(lbl)))


print("\n===== Step 3: 파일 이동 (train/val) =====")
move_pairs(train_set, train_img_dir, train_lbl_dir)
move_pairs(val_set, val_img_dir, val_lbl_dir)


print("\n===== Step 4: data.yaml 생성 =====")
yaml_path = os.path.join(BASE, "data.yaml")

data_yaml = {
    "train": "train/images",
    "val": "val/images",
    "nc": 1,
    "names": ["box"]
}

with open(yaml_path, "w") as f:
    yaml.dump(data_yaml, f, sort_keys=False)

print(f"data.yaml 생성됨 → {yaml_path}")

print("\n===== ✔ 전체 데이터셋 준비 완료 =====\n")
# Out:
# ===== Step 1: JSON 파일 삭제 =====
# 삭제됨 → color_output_2_000636.json
# 삭제됨 → frame_000590.json
# 삭제됨 → frame_000810.json
# 삭제됨 → frame_1000220.json
# 삭제됨 → color_output_1_000668.json
# 삭제됨 → frame_1000730.json
# 삭제됨 → color_output_1_000726.json
# 삭제됨 → color_output_2_000633.json
# 삭제됨 → color_output_1_000661.json
# 삭제됨 → color_output_1_001351.json
# 삭제됨 → color_output_1_003438.json
# 삭제됨 → color_output_1_000772.json
# 삭제됨 → color_output_1_001629.json
# 삭제됨 → color_output_1_000677.json
# 삭제됨 → color_output_1_001545.json
# 삭제됨 → color_output_1_002600.json
# 삭제됨 → color_output_1_000377.json
# 삭제됨 → color_output_1_001512.json
# 삭제됨 → color_output_2_000746.json
# 삭제됨 → color_output_1_002007.json
# 삭제됨 → color_output_1_001157.json
# 삭제됨 → color_output_1_000721.json
# 삭제됨 → color_output_1_002012.json
# 삭제됨 → color_output_1_002608.json
# 삭제됨 → color_output_1_001620.json
# 삭제됨 → color_output_1_001358.json
# 삭제됨 → frame_2000250.json
# 삭제됨 → color_output_1_002417.json
# 삭제됨 → color_output_1_001511.json
# 삭제됨 → color_output_1_003342.json
# 삭제됨 → color_output_1_001114.json
# 삭제됨 → color_output_1_003413.json
# 삭제됨 → color_output_1_001410.json
# 삭제됨 → color_output_2_000656.json
# 삭제됨 → frame_000310.json
# 삭제됨 → color_output_1_001875.json
# 삭제됨 → color_output_1_000745.json
# 삭제됨 → color_output_1_001510.json
# 삭제됨 → frame_000840.json
# 삭제됨 → frame_000730.json
# 삭제됨 → color_output_1_001898.json
# 삭제됨 → color_output_1_001491.json
# 삭제됨 → frame_000540.json
# 삭제됨 → frame_2000310.json
# 삭제됨 → color_output_1_000976.json
# 삭제됨 → color_output_1_001090.json
# 삭제됨 → color_output_1_001930.json
# 삭제됨 → color_output_1_002042.json
# 삭제됨 → frame_000220.json
# 삭제됨 → color_output_1_000704.json
# 삭제됨 → color_output_1_001575.json
# 삭제됨 → color_output_1_001132.json
# 삭제됨 → color_output_2_000054.json
# 삭제됨 → color_output_1_003431.json
# 삭제됨 → color_output_1_001636.json
# 삭제됨 → frame_2000540.json
# 삭제됨 → color_output_1_001183.json
# 삭제됨 → color_output_1_001960.json
# 삭제됨 → color_output_1_001353.json
# 삭제됨 → color_output_1_003461.json
# 삭제됨 → frame_2000810.json
# 삭제됨 → color_output_1_001280.json
# 삭제됨 → frame_2000590.json
# 삭제됨 → color_output_1_003445.json
# 삭제됨 → color_output_1_001915.json
# 삭제됨 → color_output_1_000673.json
# 삭제됨 → color_output_1_003548.json
# 삭제됨 → color_output_1_000894.json
# 삭제됨 → frame_1000310.json
# 삭제됨 → color_output_1_001407.json
# 삭제됨 → color_output_1_002633.json
# 삭제됨 → color_output_1_001111.json
# 삭제됨 → color_output_1_000700.json
# 삭제됨 → color_output_1_002618.json
# 삭제됨 → color_output_1_001428.json
# 삭제됨 → color_output_1_001432.json
# 삭제됨 → color_output_1_001108.json
# 삭제됨 → frame_2000210.json
# 삭제됨 → color_output_1_000685.json
# 삭제됨 → frame_1000590.json
# 삭제됨 → frame_1000250.json
# 삭제됨 → color_output_1_000725.json
# 삭제됨 → color_output_1_001165.json
# 삭제됨 → color_output_1_000370.json
# 삭제됨 → frame_2000840.json
# 삭제됨 → color_output_1_001259.json
# 삭제됨 → color_output_1_001823.json
# 삭제됨 → color_output_1_003464.json
# 삭제됨 → color_output_2_000310.json
# 삭제됨 → color_output_1_001118.json
# 삭제됨 → color_output_1_001923.json
# 삭제됨 → color_output_1_003335.json
# 삭제됨 → frame_1000810.json
# 삭제됨 → color_output_1_000499.json
# 삭제됨 → color_output_1_001902.json
# 삭제됨 → color_output_1_001105.json
# 삭제됨 → frame_2000730.json
# 삭제됨 → color_output_1_001518.json
# 삭제됨 → color_output_1_000729.json
# 삭제됨 → color_output_1_000715.json
# 삭제됨 → color_output_1_002635.json
# 삭제됨 → color_output_1_003439.json
# 삭제됨 → frame_1000540.json
# 삭제됨 → color_output_1_002925.json
# 삭제됨 → color_output_1_002604.json
# 삭제됨 → frame_000210.json
# 삭제됨 → frame_1000210.json
# 삭제됨 → color_output_1_000693.json
# 삭제됨 → color_output_1_000718.json
# 삭제됨 → frame_1000840.json
# 삭제됨 → color_output_2_000730.json
# 삭제됨 → color_output_1_000671.json
# 삭제됨 → color_output_1_001957.json
# 삭제됨 → color_output_1_000708.json
# 삭제됨 → frame_2000220.json
# 삭제됨 → color_output_1_002403.json
# 삭제됨 → frame_000250.json
# 삭제됨 → color_output_2_000313.json
# 삭제됨 → color_output_1_001626.json
# 삭제됨 → color_output_1_003414.json
# 삭제됨 → color_output_1_001196.json
# 삭제됨 → color_output_1_000658.json
# 삭제됨 → color_output_1_003513.json
# 삭제됨 → color_output_1_001352.json
# 삭제됨 → color_output_1_001115.json
# 삭제됨 → color_output_1_001117.json
# 삭제됨 → color_output_1_000697.json
#
# ===== Step 2: 이미지 + 라벨 파일 수집 =====
# 이미지: 127개
# 라벨: 127개
# Train: 102개
# Val:   25개
#
# ===== Step 3: 파일 이동 (train/val) =====
#
# ===== Step 4: data.yaml 생성 =====
# data.yaml 생성됨 → /home/dw/ws_job_msislab/amr_project/for_training/20251218_obb/data.yaml
#
# ===== ✔ 전체 데이터셋 준비 완료 =====

# %%
from ultralytics import YOLO

# ----------------------------------------------------
# 1) YOLO11S-OBB 모델 로드
# ----------------------------------------------------
model = YOLO("yolo11s-obb.pt")   # OBB 전용 pretrained 모델

# ----------------------------------------------------
# 2) DATA.YAML 경로
# ----------------------------------------------------
DATA_PATH = "/home/dw/ws_job_msislab/amr_project/for_training/20251218_obb/data.yaml"

# ----------------------------------------------------
# 3) 학습 실행
# ----------------------------------------------------
model.train(
    # ---------- 필수 ----------
    data=DATA_PATH,
    epochs=500,                # 스모크 테스트
    imgsz=640,
    batch=4,
    device=0,
    workers=2,

    # ---------- 실험 관리 ----------
    project="runs/obb",      # runs/obb 아래로 정리
    name="smoke_test_v2",    # 실험 이름
    exist_ok=True,           # 같은 이름 덮어쓰기 허용
    seed=25,                 # 재현성 확보
    deterministic=True,

    # ---------- Optimizer / LR ----------
    optimizer="AdamW",       # OBB에서 비교적 안정적
    lr0=1e-3,                # 초기 learning rate
    lrf=0.01,                # 최종 LR 비율
    cos_lr=True,             # cosine scheduler

    # ---------- 학습 안정성 ----------
    patience=15,             # early stopping (스모크라 사실상 의미 없음)
    warmup_epochs=1,
    amp=True,                # mixed precision (GPU 메모리 절약)

    # ---------- 데이터 로딩 ----------
    cache="ram",             # 데이터 적으면 RAM 캐시 추천
    rect=False,              # OBB는 보통 False 권장

    # ---------- Augmentation (OBB 기준 보수적으로) ----------
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    degrees=5.0,             # 회전은 OBB 특성상 소량만
    translate=0.1,
    scale=0.5,
    shear=2.0,
    flipud=0.0,
    fliplr=0.5,
    mosaic=0.5,
    mixup=0.0,

    # ---------- 저장 / 로그 ----------
    save=True,
    save_period=0,           # epoch마다 weight 저장
    plots=True,              # loss, metrics plot 생성
    verbose=True,
)

print("\n🎉 Training Finished! Check the 'runs/obb/smoke_test_v1' folder.")
# Out:
# New https://pypi.org/project/ultralytics/8.3.240 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.239 🚀 Python-3.10.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 7932MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=ram, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/home/dw/ws_job_msislab/amr_project/for_training/20251218_obb/data.yaml, degrees=5.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=500, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s-obb.pt, momentum=0.937, mosaic=0.5, multi_scale=False, name=smoke_test_v2, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/obb, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/dw/ws_job_msislab/amr_project/src/runs/obb/smoke_test_v2, save_frames=False, save_json=False, save_period=0, save_txt=False, scale=0.5, seed=25, shear=2.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=obb, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=1, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1   1105974  ultralytics.nn.modules.head.OBB              [1, 1, [128, 256, 512]]
# YOLO11s-obb summary: 196 layers, 9,714,358 parameters, 9,714,342 gradients, 22.5 GFLOPs
#
# Transferred 535/541 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4778.6±1354.5 MB/s, size: 134.0 KB)
# train: Scanning /home/dw/ws_job_msislab/amr_project/for_training/20251218_obb/train/labels... 102 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 102/102 3.2Kit/s 0.0s
# train: New cache created: /home/dw/ws_job_msislab/amr_project/for_training/20251218_obb/train/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (0.1GB RAM): 100% ━━━━━━━━━━━━ 102/102 1.9Kit/s 0.1s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3247.2±2284.3 MB/s, size: 116.5 KB)
# val: Scanning /home/dw/ws_job_msislab/amr_project/for_training/20251218_obb/val/labels... 25 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 25/25 2.4Kit/s 0.0s
# val: New cache created: /home/dw/ws_job_msislab/amr_project/for_training/20251218_obb/val/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.0GB RAM): 100% ━━━━━━━━━━━━ 25/25 1.1Kit/s 0.0s
# Plotting labels to /home/dw/ws_job_msislab/amr_project/src/runs/obb/smoke_test_v2/labels.jpg...
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 87 weight(decay=0.0), 97 weight(decay=0.0005), 96 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /home/dw/ws_job_msislab/amr_project/src/runs/obb/smoke_test_v2
# Starting training for 500 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/500      1.22G     0.7572      2.053      1.833         12        640: 100% ━━━━━━━━━━━━ 26/26 2.1it/s 12.3s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.7it/s 2.6s<0.1s
#                    all         25         81       0.97      0.877      0.982      0.864
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/500      1.28G     0.5746      0.892      1.587          4        640: 100% ━━━━━━━━━━━━ 26/26 20.6it/s 1.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 48.8it/s 0.1s0.1s
#                    all         25         81      0.998          1      0.995      0.905
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/500      1.35G     0.5564     0.7241      1.508          9        640: 100% ━━━━━━━━━━━━ 26/26 21.5it/s 1.2s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 49.4it/s 0.1s0.1s
#                    all         25         81          1      0.996      0.995      0.932
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/500      1.41G     0.5317     0.6022      1.424         10        640: 100% ━━━━━━━━━━━━ 26/26 21.5it/s 1.2s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 50.3it/s 0.1s0.1s
#                    all         25         81      0.984          1      0.995      0.945
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/500      1.45G     0.5496     0.5887      1.405          9        640: 100% ━━━━━━━━━━━━ 26/26 21.6it/s 1.2s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 49.6it/s 0.1s0.1s
#                    all         25         81      0.988          1      0.995      0.945
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/500      1.51G     0.5319     0.5539      1.403          6        640: 100% ━━━━━━━━━━━━ 26/26 21.2it/s 1.2s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 49.2it/s 0.1s0.1s
#                    all         25         81      0.987          1      0.995      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/500      1.62G      0.517     0.5206      1.465          8        640: 100% ━━━━━━━━━━━━ 26/26 21.3it/s 1.2s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 49.9it/s 0.1s0.1s
#                    all         25         81      0.988          1      0.995      0.964
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/500      1.66G     0.5125     0.5259      1.283          2        640: 100% ━━━━━━━━━━━━ 26/26 21.4it/s 1.2s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 50.5it/s 0.1s0.1s
#                    all         25         81       0.99          1      0.995      0.966
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/500       1.7G     0.4575     0.4845      1.322          8        640: 100% ━━━━━━━━━━━━ 26/26 21.0it/s 1.2s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 50
# EarlyStopping: Training stopped early as no improvement observed in last 15 epochs. Best results observed at epoch 46, best model saved as best.pt.
# To update EarlyStopping(patience=15) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 61 epochs completed in 0.031 hours.
# Optimizer stripped from /home/dw/ws_job_msislab/amr_project/src/runs/obb/smoke_test_v2/weights/last.pt, 19.8MB
# Optimizer stripped from /home/dw/ws_job_msislab/amr_project/src/runs/obb/smoke_test_v2/weights/best.pt, 19.8MB
#
# Validating /home/dw/ws_job_msislab/amr_project/src/runs/obb/smoke_test_v2/weights/best.pt...
# Ultralytics 8.3.239 🚀 Python-3.10.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 7932MiB)
# YOLO11s-obb summary (fused): 109 layers, 9,699,174 parameters, 0 gradients, 22.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 37.6it/s 0.2s.3s
#                    all         25         81      0.998          1      0.995      0.994
# Speed: 0.2ms preprocess, 1.9ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to /home/dw/ws_job_msislab/amr_project/src/runs/obb/smoke_test_v2
#
# 🎉 Training Finished! Check the 'runs/obb/smoke_test_v1' folder.

# %%
from ultralytics import YOLO
import os
import glob
import cv2

# -------------------------------------------------------
# 1) 모델 로드
# -------------------------------------------------------
MODEL_PATH = "/home/dw/ws_job_msislab/amr_project/src/runs/obb/smoke_test_v1/weights/best.pt"
model = YOLO(MODEL_PATH)

# -------------------------------------------------------
# 2) 루트 이미지 폴더
# -------------------------------------------------------
ROOT = "/home/dw/ws_job_msislab/amr_project/data/image_data/for_yolo_obj/20251210"

# 서브폴더까지 모든 이미지 검색
img_list = []
for ext in ["*.jpg", "*.png", "*.jpeg", "*.JPG", "*.PNG"]:
    img_list.extend(glob.glob(f"{ROOT}/**/{ext}", recursive=True))

print(f"[INFO] 총 {len(img_list)}장의 이미지를 inference 합니다.")

# -------------------------------------------------------
# 3) 출력 폴더
# -------------------------------------------------------
OUT_DIR = os.path.join(ROOT, "obb_viz")
os.makedirs(OUT_DIR, exist_ok=True)

# -------------------------------------------------------
# 4) inference + 시각화 저장
# -------------------------------------------------------
for img_path in img_list:
    file_name = os.path.basename(img_path)
    out_path = os.path.join(OUT_DIR, file_name)

    results = model(img_path)
    plotted = results[0].plot()

    cv2.imwrite(out_path, plotted)
    print(f"[OK] {out_path} 저장됨")

print("\n🎉 완료! obb_viz 폴더에서 시각화 결과 확인!")

# %% [markdown]
# ### obb 각도랑 뭐시기

# %%
from ultralytics import YOLO
import os
import glob
import cv2
import numpy as np
import math

# -------------------------------------------------------
# 1) 모델 로드
# -------------------------------------------------------
MODEL_PATH = "/home/dw/ws_job_msislab/amr_project/src/runs/obb/smoke_test_v1/weights/best.pt"
model = YOLO(MODEL_PATH)

# -------------------------------------------------------
# 2) 루트 이미지 폴더
# -------------------------------------------------------
ROOT = "/home/dw/ws_job_msislab/amr_project/data/image_data/for_yolo_obj/20251210"

img_list = []
for ext in ["*.jpg", "*.png", "*.jpeg", "*.JPG", "*.PNG"]:
    img_list.extend(glob.glob(f"{ROOT}/**/{ext}", recursive=True))

print(f"[INFO] 총 {len(img_list)}장의 이미지를 inference 합니다.")

# -------------------------------------------------------
# 3) 출력 폴더
# -------------------------------------------------------
OUT_DIR = os.path.join(ROOT, "obb_viz")
os.makedirs(OUT_DIR, exist_ok=True)

# -------------------------------------------------------
# 4) inference + 커스텀 시각화
# -------------------------------------------------------
for img_path in img_list:
    img = cv2.imread(img_path)
    if img is None:
        continue

    results = model(img)
    r = results[0]

    if r.obb is None:
        continue

    boxes = r.obb.xyxyxyxy.cpu().numpy()   # (N, 4, 2)
    confs = r.obb.conf.cpu().numpy()

    for box, conf in zip(boxes, confs):
        # -------------------------------
        # OBB 좌표
        # -------------------------------
        pts_int = box.astype(np.int32)     # 시각화용
        pts = box.astype(np.float32)       # 계산용

        # -------------------------------
        # OBB 외곽선
        # -------------------------------
        cv2.polylines(img, [pts_int], True, (255, 0, 0), 2)

        # -------------------------------
        # 중심점
        # -------------------------------
        cx, cy = pts.mean(axis=0)
        cx_i, cy_i = int(cx), int(cy)

        # -------------------------------
        # 박스 방향 벡터 (장축 / 단축)
        # -------------------------------
        p0, p1, p2, p3 = pts

        v_long = p1 - p0
        v_short = p2 - p1

        len_long = np.linalg.norm(v_long)
        len_short = np.linalg.norm(v_short)

        if len_long < 1 or len_short < 1:
            continue

        v_long /= len_long
        v_short /= len_short

        # -------------------------------------------------
        # 🔥 장축 벡터 방향 통일: 항상 "위쪽(Y-)"을 향하게
        #    (부호 튐 방지 핵심)
        # -------------------------------------------------
        if v_long[1] > 0:      # 아래쪽(+y)을 향하면
            v_long = -v_long   # 위쪽(-y)으로 뒤집기

        # -------------------------------
        # 박스 전체 십자가 (회전 포함)
        # -------------------------------
        long_p1 = (
            int(cx - v_long[0] * len_long / 2),
            int(cy - v_long[1] * len_long / 2),
        )
        long_p2 = (
            int(cx + v_long[0] * len_long / 2),
            int(cy + v_long[1] * len_long / 2),
        )

        short_p1 = (
            int(cx - v_short[0] * len_short / 2),
            int(cy - v_short[1] * len_short / 2),
        )
        short_p2 = (
            int(cx + v_short[0] * len_short / 2),
            int(cy + v_short[1] * len_short / 2),
        )

        cv2.line(img, long_p1, long_p2, (0, 255, 255), 2)
        cv2.line(img, short_p1, short_p2, (0, 255, 255), 2)

        # -------------------------------
        # ✅ 회전 각도 (수직 기준)
        #   0°  : 정자세 (세로)
        #   +   : 오른쪽 기울어짐
        #   -   : 왼쪽 기울어짐
        # -------------------------------
        # [중요] 여기만 "부호 확정" 로직을 추가함 (나머진 그대로)
        v_ref = np.array([0.0, -1.0], dtype=np.float32)  # 수직(위쪽) 기준

        # 1) 각도 크기 (0~180) 중 실제론 0~90 근처로 나옴
        cos_theta = float(np.clip(np.dot(v_long, v_ref), -1.0, 1.0))
        angle_abs = math.degrees(math.acos(cos_theta))

        # 2) 부호: 외적 z성분으로 좌/우 결정
        #   cross > 0  => 오른쪽 기울(+) / cross < 0 => 왼쪽 기울(-)
        cross = v_ref[0] * v_long[1] - v_ref[1] * v_long[0]
        angle = angle_abs if cross > 0 else -angle_abs

        # -------------------------------
        # 각도 텍스트
        # -------------------------------
        label = f"{angle:.1f} deg"
        cv2.putText(
            img,
            label,
            (cx_i - 40, cy_i - 10),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.6,
            (0, 0, 255),
            2,
        )

    # -------------------------------
    # 결과 저장
    # -------------------------------
    out_path = os.path.join(OUT_DIR, os.path.basename(img_path))
    cv2.imwrite(out_path, img)
    print(f"[OK] {out_path}")

print("\n🎉 완료! 수직 기준 각도(+/-) + 십자가 시각화 결과 확인")

# %% [markdown]
# ### obb시각화 2번째

# %%
from ultralytics import YOLO
import os
import glob
import cv2
import numpy as np
import math

# -------------------------------------------------------
# 1) 모델 로드
# -------------------------------------------------------
MODEL_PATH = "/home/dw/ws_job_msislab/amr_project/src/runs/obb/smoke_test_v1/weights/best.pt"
model = YOLO(MODEL_PATH)

# -------------------------------------------------------
# 2) 루트 이미지 폴더
# -------------------------------------------------------
ROOT = "/home/dw/ws_job_msislab/amr_project/data/image_data/for_yolo_obj/20251210"

img_list = []
for ext in ["*.jpg", "*.png", "*.jpeg", "*.JPG", "*.PNG"]:
    img_list.extend(glob.glob(f"{ROOT}/**/{ext}", recursive=True))

print(f"[INFO] 총 {len(img_list)}장의 이미지를 inference 합니다.")

# -------------------------------------------------------
# 3) 출력 폴더
# -------------------------------------------------------
OUT_DIR = os.path.join(ROOT, "obb_viz")
os.makedirs(OUT_DIR, exist_ok=True)

# -------------------------------------------------------
# 4) inference + 커스텀 시각화
# -------------------------------------------------------
for img_path in img_list:
    img = cv2.imread(img_path)
    if img is None:
        continue

    results = model(img)
    r = results[0]

    if r.obb is None:
        continue

    boxes = r.obb.xyxyxyxy.cpu().numpy()   # (N, 4, 2)
    confs = r.obb.conf.cpu().numpy()

    for box, conf in zip(boxes, confs):
        # -------------------------------
        # OBB 좌표
        # -------------------------------
        pts_int = box.astype(np.int32)     # 시각화용
        pts = box.astype(np.float32)       # 계산용

        # -------------------------------
        # OBB 외곽선
        # -------------------------------
        cv2.polylines(img, [pts_int], True, (255, 0, 0), 2)

        # -------------------------------
        # 중심점
        # -------------------------------
        cx, cy = pts.mean(axis=0)
        cx_i, cy_i = int(cx), int(cy)

        # -------------------------------
        # 박스 방향 벡터 (장축 / 단축)  ✅ 여기 핵심 수정
        # -------------------------------
        p0, p1, p2, p3 = pts

        e01 = p1 - p0
        e12 = p2 - p1

        len01 = np.linalg.norm(e01)
        len12 = np.linalg.norm(e12)

        if len01 < 1 or len12 < 1:
            continue

        # ✅ 더 긴 변을 장축(long)으로 선택
        if len01 >= len12:
            v_long = e01
            v_short = e12
            len_long = len01
            len_short = len12
        else:
            v_long = e12
            v_short = e01
            len_long = len12
            len_short = len01

        # 정규화
        v_long /= len_long
        v_short /= len_short

        # -------------------------------------------------
        # 🔥 장축 벡터 방향 통일: 항상 "위쪽(Y-)"을 향하게
        # -------------------------------------------------
        if v_long[1] > 0:      # 아래쪽(+y)을 향하면
            v_long = -v_long   # 위쪽(-y)으로 뒤집기

        # -------------------------------
        # 박스 전체 십자가 (회전 포함)
        # -------------------------------
        long_p1 = (
            int(cx - v_long[0] * len_long / 2),
            int(cy - v_long[1] * len_long / 2),
        )
        long_p2 = (
            int(cx + v_long[0] * len_long / 2),
            int(cy + v_long[1] * len_long / 2),
        )

        short_p1 = (
            int(cx - v_short[0] * len_short / 2),
            int(cy - v_short[1] * len_short / 2),
        )
        short_p2 = (
            int(cx + v_short[0] * len_short / 2),
            int(cy + v_short[1] * len_short / 2),
        )

        cv2.line(img, long_p1, long_p2, (0, 255, 255), 2)
        cv2.line(img, short_p1, short_p2, (0, 255, 255), 2)

        # -------------------------------
        # ✅ 회전 각도 (수직 기준)
        #   0°  : 정자세 (세로)
        #   +   : 오른쪽 기울어짐
        #   -   : 왼쪽 기울어짐
        # -------------------------------
        angle = math.degrees(math.atan2(v_long[0], -v_long[1]))

        # -------------------------------
        # 각도 텍스트
        # -------------------------------
        label = f"{angle:.1f} deg"
        cv2.putText(
            img,
            label,
            (cx_i - 40, cy_i - 10),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.6,
            (0, 0, 255),
            2,
        )

    # -------------------------------
    # 결과 저장
    # -------------------------------
    out_path = os.path.join(OUT_DIR, os.path.basename(img_path))
    cv2.imwrite(out_path, img)
    print(f"[OK] {out_path}")

print("\n🎉 완료! 수직 기준 각도(+/-) + 십자가 시각화 결과 확인")

# %%
from ultralytics import YOLO
import pyrealsense2 as rs
import numpy as np
import cv2
import math
import time

# -------------------------------------------------------
# 0) 설정
# -------------------------------------------------------
MODEL_PATH = "/home/dw/ws_job_msislab/amr_project/src/runs/obb/smoke_test_v1/weights/best.pt"
CONF_TH = 0.25
IMGSZ = 640
DEVICE = 0  # GPU 없으면 "cpu"

COLOR_W, COLOR_H, FPS = 640, 480, 30
DEPTH_W, DEPTH_H = 640, 480

# depth 샘플링: 중심 주변에서 N x N 픽셀을 뽑아 median
DEPTH_PATCH = 9          # 홀수 권장 (예: 5, 7, 9, 11)
DEPTH_MIN_M = 0.10       # 유효 depth 최소
DEPTH_MAX_M = 2.50       # 유효 depth 최대

# -------------------------------------------------------
# 1) YOLO 로드
# -------------------------------------------------------
model = YOLO(MODEL_PATH)

# -------------------------------------------------------
# 2) RealSense 파이프라인
# -------------------------------------------------------
pipeline = rs.pipeline()
config = rs.config()
config.enable_stream(rs.stream.color, COLOR_W, COLOR_H, rs.format.bgr8, FPS)
config.enable_stream(rs.stream.depth, DEPTH_W, DEPTH_H, rs.format.z16, FPS)

profile = pipeline.start(config)

# color에 depth 정렬
align = rs.align(rs.stream.color)

# intrinsics (color stream 기준)
color_stream = profile.get_stream(rs.stream.color).as_video_stream_profile()
intr = color_stream.get_intrinsics()
fx, fy, ppx, ppy = intr.fx, intr.fy, intr.ppx, intr.ppy

print("[INFO] RealSense started")
print(f"[INFO] intrinsics: fx={fx:.2f}, fy={fy:.2f}, ppx={ppx:.2f}, ppy={ppy:.2f}")
print("[INFO] Press 'q' to quit")

def median_depth_in_patch(depth_frame, u, v, patch=9):
    """
    (u,v) 중심 주변 patch x patch 영역의 depth(m) median 반환.
    depth_frame은 align된 depth_frame이어야 함.
    """
    half = patch // 2
    h, w = depth_frame.get_height(), depth_frame.get_width()

    u0 = max(0, u - half)
    u1 = min(w - 1, u + half)
    v0 = max(0, v - half)
    v1 = min(h - 1, v + half)

    vals = []
    for yy in range(v0, v1 + 1):
        for xx in range(u0, u1 + 1):
            d = depth_frame.get_distance(xx, yy)  # meters
            if DEPTH_MIN_M <= d <= DEPTH_MAX_M:
                vals.append(d)

    if not vals:
        return None
    return float(np.median(vals))

def compute_obb_axes_and_angle(pts):
    """
    pts: (4,2) float32, OBB 4점(시계방향)
    return:
      cx,cy (float), v_long(unit), v_short(unit),
      len_long(px), len_short(px),
      angle_deg (vertical 기준 0°, 오른쪽 +, 왼쪽 -)
    """
    cx, cy = pts.mean(axis=0)

    p0, p1, p2, p3 = pts

    e01 = p1 - p0
    e12 = p2 - p1

    len01 = np.linalg.norm(e01)
    len12 = np.linalg.norm(e12)
    if len01 < 1e-6 or len12 < 1e-6:
        return None

    # 더 긴 변을 장축으로 선택 (너 케이스 70도 튐 해결)
    if len01 >= len12:
        v_long = e01
        v_short = e12
        len_long, len_short = len01, len12
    else:
        v_long = e12
        v_short = e01
        len_long, len_short = len12, len01

    v_long = v_long / (len_long + 1e-12)
    v_short = v_short / (len_short + 1e-12)

    # 장축 방향 통일: 항상 위쪽(-y) 향하도록 (부호 안정화)
    if v_long[1] > 0:
        v_long = -v_long

    # 세로 기준 각도:
    # 0° = 위쪽(-y)과 일치
    # 오른쪽 기울면 +, 왼쪽 기울면 -
    angle_deg = math.degrees(math.atan2(v_long[0], -v_long[1]))

    return cx, cy, v_long, v_short, float(len_long), float(len_short), float(angle_deg)

try:
    while True:
        frames = pipeline.wait_for_frames()
        frames = align.process(frames)

        depth_frame = frames.get_depth_frame()
        color_frame = frames.get_color_frame()
        if not depth_frame or not color_frame:
            continue

        color = np.asanyarray(color_frame.get_data())

        # ---------------------------
        # YOLO OBB inference
        # ---------------------------
        results = model.predict(
            source=color,
            imgsz=IMGSZ,
            conf=CONF_TH,
            device=DEVICE,
            verbose=False
        )
        r = results[0]

        if r.obb is not None and len(r.obb) > 0:
            boxes = r.obb.xyxyxyxy.cpu().numpy()  # (N,4,2)
            confs = r.obb.conf.cpu().numpy()

            # 가장 높은 conf 1개만 선택(테스트용)
            best_i = int(np.argmax(confs))
            box = boxes[best_i]
            conf = float(confs[best_i])

            pts_i = box.astype(np.int32)
            pts = box.astype(np.float32)

            # OBB 외곽선
            cv2.polylines(color, [pts_i], True, (255, 0, 0), 2)

            axes = compute_obb_axes_and_angle(pts)
            if axes is not None:
                cx, cy, v_long, v_short, len_long, len_short, angle_deg = axes
                cx_i, cy_i = int(cx), int(cy)

                # 박스 전체 십자가
                long_p1 = (int(cx - v_long[0]*len_long/2), int(cy - v_long[1]*len_long/2))
                long_p2 = (int(cx + v_long[0]*len_long/2), int(cy + v_long[1]*len_long/2))
                short_p1 = (int(cx - v_short[0]*len_short/2), int(cy - v_short[1]*len_short/2))
                short_p2 = (int(cx + v_short[0]*len_short/2), int(cy + v_short[1]*len_short/2))
                cv2.line(color, long_p1, long_p2, (0, 255, 255), 2)
                cv2.line(color, short_p1, short_p2, (0, 255, 255), 2)

                # depth (중심 주변 median)
                Z = median_depth_in_patch(depth_frame, cx_i, cy_i, patch=DEPTH_PATCH)

                if Z is not None:
                    # deproject: pixel + depth -> 3D (camera frame)
                    X, Y, Zm = rs.rs2_deproject_pixel_to_point(intr, [cx_i, cy_i], Z)
                    # rs2_deproject_pixel_to_point returns [X,Y,Z] in meters
                    dist = math.sqrt(X*X + Y*Y + Zm*Zm)

                    text1 = f"conf={conf:.2f}  angle={angle_deg:+.1f} deg"
                    text2 = f"cam XYZ=({X:+.3f},{Y:+.3f},{Zm:+.3f}) m  dist={dist:.3f} m"
                else:
                    text1 = f"conf={conf:.2f}  angle={angle_deg:+.1f} deg"
                    text2 = "depth: N/A (try adjust DEPTH_PATCH / object surface)"

                cv2.putText(color, text1, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
                cv2.putText(color, text2, (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

        cv2.imshow("YOLO11-OBB + Depth (Camera frame)", color)
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break

finally:
    pipeline.stop()
    cv2.destroyAllWindows()
    print("[INFO] stopped")
