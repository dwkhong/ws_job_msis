# %%
from pathlib import Path

# 경로 설정
IMG_DIR = Path("/home/dw/ws_job_msislab/Golf_Project/data/for_study/20251010_merge_data/images")
IMG_EXTS = {".jpg", ".jpeg", ".png", ".bmp", ".webp",
            ".JPG", ".JPEG", ".PNG", ".BMP", ".WEBP"}

count = 0
bad_files = []  # 혹시 확인하고 싶은 제외된 파일

for img in IMG_DIR.rglob("*"):
    if not img.is_file() or img.suffix not in IMG_EXTS:
        continue
    name_lower = img.name.lower()
    # 제외 조건
    if "dup" in name_lower:
        bad_files.append(img)
        continue
    if name_lower.count("bg") >= 2:
        bad_files.append(img)
        continue
    count += 1

print("오리지널 이미지 개수:", count)
print("제외된 파일 수:", len(bad_files))
# Out:
# 오리지널 이미지 개수: 5455
# 제외된 파일 수: 2954

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

from pathlib import Path
from collections import Counter
from typing import List
import pandas as pd
from IPython.display import display

# -------------------- 기본 경로/설정 --------------------
BASE = Path("/home/dw/ws_job_msislab/Golf_Project/data/for_study/20251017_merge_data")
IMAGES_DIR = BASE / "images"
LABELS_DIR = BASE / "labels"

DATE_TOKENS = {
    "20250721": "0721",
    "20250725": "0725",
    "20250904": "0904",
    "20250929": "0929",
    "20250930": "0930",
}
# 열 순서: Total → 0904 → 0725 → 0721
COLS = ["Total", "0930","0929","0904", "0725", "0721"]

# 클래스 이름 매핑
CLASS_ORDER = [
    "Divot", "Fixed_Divot", "Diseased_Grass", "Confused_Object",
    "Pole", "Sprinkler", "Drain", "Golf ball"
]
ROWS = ["Image", "bg"] + CLASS_ORDER

IMG_EXTS = {".jpg", ".jpeg", ".png", ".bmp", ".webp",
            ".JPG", ".JPEG", ".PNG", ".BMP", ".WEBP"}

# -------------------- 유틸 함수 --------------------
def detect_date(name: str):
    for token, col in DATE_TOKENS.items():
        if token in name:
            return col
    return None

def read_label_ids(txt_path: Path) -> List[int]:
    """YOLO txt를 읽어서 class id 리스트 리턴 (한 줄의 첫 토큰만 사용)"""
    try:
        if not txt_path.exists():
            return []
        txt = txt_path.read_text(encoding="utf-8", errors="ignore").strip()
        if not txt:
            return []
        ids = []
        for ln in txt.splitlines():
            ln = ln.strip()
            if not ln:
                continue
            first = ln.split()[0]
            try:
                cid = int(float(first))
            except Exception:
                continue
            ids.append(cid)
        return ids
    except Exception:
        return []

# -------------------- 메인 로직 --------------------
def build_table() -> pd.DataFrame:
    table = {row: Counter({c: 0 for c in COLS}) for row in ROWS}

    for img in IMAGES_DIR.rglob("*"):
        if not img.is_file() or img.suffix not in IMG_EXTS:
            continue

        name_lower = img.name.lower()

        # ✅ 제외 조건: dup 포함 또는 'bg'가 2회 이상 등장하면 전체 집계에서 제외
        if "dup" in name_lower or name_lower.count("bg") >= 2:
            continue

        col = detect_date(name_lower)
        if not col:
            continue

        # 이미지 카운트
        table["Image"][col] += 1
        table["Image"]["Total"] += 1

        # 라벨 경로 매핑
        rel = img.relative_to(IMAGES_DIR)
        label_path = (LABELS_DIR / rel).with_suffix(".txt")
        label_ids = read_label_ids(label_path)

        # bg: 파일명에 "bg"가 정확히 1번 포함 & 라벨 비어있음
        if name_lower.count("bg") == 1 and len(label_ids) == 0:
            table["bg"][col] += 1
            table["bg"]["Total"] += 1

        # 클래스 카운트 (0~7)
        for cid in label_ids:
            if 0 <= cid <= 7:
                row = CLASS_ORDER[cid]
                table[row][col] += 1
                table[row]["Total"] += 1

    # DataFrame 생성 (행/열 순서 고정)
    df = pd.DataFrame(
        {c: [table[row][c] for row in ROWS] for c in COLS},
        index=ROWS
    ).astype(int)

    return df

# -------------------- 실행 & 출력 --------------------
df_counts = build_table()

# Styler로 중앙정렬 적용
styled = (df_counts.style
          .set_properties(**{"text-align": "center"})
          .set_table_styles([dict(selector="th", props=[("text-align", "center")])]))

display(styled)
# Out:
# <style type="text/css">
# #T_f641e th {
#   text-align: center;
# }
# #T_f641e_row0_col0, #T_f641e_row0_col1, #T_f641e_row0_col2, #T_f641e_row0_col3, #T_f641e_row0_col4, #T_f641e_row0_col5, #T_f641e_row1_col0, #T_f641e_row1_col1, #T_f641e_row1_col2, #T_f641e_row1_col3, #T_f641e_row1_col4, #T_f641e_row1_col5, #T_f641e_row2_col0, #T_f641e_row2_col1, #T_f641e_row2_col2, #T_f641e_row2_col3, #T_f641e_row2_col4, #T_f641e_row2_col5, #T_f641e_row3_col0, #T_f641e_row3_col1, #T_f641e_row3_col2, #T_f641e_row3_col3, #T_f641e_row3_col4, #T_f641e_row3_col5, #T_f641e_row4_col0, #T_f641e_row4_col1, #T_f641e_row4_col2, #T_f641e_row4_col3, #T_f641e_row4_col4, #T_f641e_row4_col5, #T_f641e_row5_col0, #T_f641e_row5_col1, #T_f641e_row5_col2, #T_f641e_row5_col3, #T_f641e_row5_col4, #T_f641e_row5_col5, #T_f641e_row6_col0, #T_f641e_row6_col1, #T_f641e_row6_col2, #T_f641e_row6_col3, #T_f641e_row6_col4, #T_f641e_row6_col5, #T_f641e_row7_col0, #T_f641e_row7_col1, #T_f641e_row7_col2, #T_f641e_row7_col3, #T_f641e_row7_col4, #T_f641e_row7_col5, #T_f641e_row8_col0, #T_f641e_row8_col1, #T_f641e_row8_col2, #T_f641e_row8_col3, #T_f641e_row8_col4, #T_f641e_row8_col5, #T_f641e_row9_col0, #T_f641e_row9_col1, #T_f641e_row9_col2, #T_f641e_row9_col3, #T_f641e_row9_col4, #T_f641e_row9_col5 {
#   text-align: center;
# }
# </style>
# <table id="T_f641e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f641e_level0_col0" class="col_heading level0 col0" >Total</th>
#       <th id="T_f641e_level0_col1" class="col_heading level0 col1" >0930</th>
#       <th id="T_f641e_level0_col2" class="col_heading level0 col2" >0929</th>
#       <th id="T_f641e_level0_col3" class="col_heading level0 col3" >0904</th>
#       <th id="T_f641e_level0_col4" class="col_heading level0 col4" >0725</th>
#       <th id="T_f641e_level0_col5" class="col_heading level0 col5" >0721</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f641e_level0_row0" class="row_heading level0 row0" >Image</th>
#       <td id="T_f641e_row0_col0" class="data row0 col0" >5367</td>
#       <td id="T_f641e_row0_col1" class="data row0 col1" >792</td>
#       <td id="T_f641e_row0_col2" class="data row0 col2" >357</td>
#       <td id="T_f641e_row0_col3" class="data row0 col3" >3215</td>
#       <td id="T_f641e_row0_col4" class="data row0 col4" >440</td>
#       <td id="T_f641e_row0_col5" class="data row0 col5" >563</td>
#     </tr>
#     <tr>
#       <th id="T_f641e_level0_row1" class="row_heading level0 row1" >bg</th>
#       <td id="T_f641e_row1_col0" class="data row1 col0" >132</td>
#       <td id="T_f641e_row1_col1" class="data row1 col1" >28</td>
#       <td id="T_f641e_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_f641e_row1_col3" class="data row1 col3" >29</td>
#       <td id="T_f641e_row1_col4" class="data row1 col4" >45</td>
#       <td id="T_f641e_row1_col5" class="data row1 col5" >30</td>
#     </tr>
#     <tr>
#       <th id="T_f641e_level0_row2" class="row_heading level0 row2" >Divot</th>
#       <td id="T_f641e_row2_col0" class="data row2 col0" >5995</td>
#       <td id="T_f641e_row2_col1" class="data row2 col1" >1545</td>
#       <td id="T_f641e_row2_col2" class="data row2 col2" >394</td>
#       <td id="T_f641e_row2_col3" class="data row2 col3" >3305</td>
#       <td id="T_f641e_row2_col4" class="data row2 col4" >196</td>
#       <td id="T_f641e_row2_col5" class="data row2 col5" >555</td>
#     </tr>
#     <tr>
#       <th id="T_f641e_level0_row3" class="row_heading level0 row3" >Fixed_Divot</th>
#       <td id="T_f641e_row3_col0" class="data row3 col0" >8542</td>
#       <td id="T_f641e_row3_col1" class="data row3 col1" >2179</td>
#       <td id="T_f641e_row3_col2" class="data row3 col2" >1171</td>
#       <td id="T_f641e_row3_col3" class="data row3 col3" >4093</td>
#       <td id="T_f641e_row3_col4" class="data row3 col4" >542</td>
#       <td id="T_f641e_row3_col5" class="data row3 col5" >557</td>
#     </tr>
#     <tr>
#       <th id="T_f641e_level0_row4" class="row_heading level0 row4" >Diseased_Grass</th>
#       <td id="T_f641e_row4_col0" class="data row4 col0" >679</td>
#       <td id="T_f641e_row4_col1" class="data row4 col1" >67</td>
#       <td id="T_f641e_row4_col2" class="data row4 col2" >65</td>
#       <td id="T_f641e_row4_col3" class="data row4 col3" >505</td>
#       <td id="T_f641e_row4_col4" class="data row4 col4" >22</td>
#       <td id="T_f641e_row4_col5" class="data row4 col5" >20</td>
#     </tr>
#     <tr>
#       <th id="T_f641e_level0_row5" class="row_heading level0 row5" >Confused_Object</th>
#       <td id="T_f641e_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_f641e_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_f641e_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_f641e_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_f641e_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_f641e_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f641e_level0_row6" class="row_heading level0 row6" >Pole</th>
#       <td id="T_f641e_row6_col0" class="data row6 col0" >126</td>
#       <td id="T_f641e_row6_col1" class="data row6 col1" >19</td>
#       <td id="T_f641e_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_f641e_row6_col3" class="data row6 col3" >95</td>
#       <td id="T_f641e_row6_col4" class="data row6 col4" >12</td>
#       <td id="T_f641e_row6_col5" class="data row6 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f641e_level0_row7" class="row_heading level0 row7" >Sprinkler</th>
#       <td id="T_f641e_row7_col0" class="data row7 col0" >67</td>
#       <td id="T_f641e_row7_col1" class="data row7 col1" >7</td>
#       <td id="T_f641e_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_f641e_row7_col3" class="data row7 col3" >34</td>
#       <td id="T_f641e_row7_col4" class="data row7 col4" >26</td>
#       <td id="T_f641e_row7_col5" class="data row7 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f641e_level0_row8" class="row_heading level0 row8" >Drain</th>
#       <td id="T_f641e_row8_col0" class="data row8 col0" >315</td>
#       <td id="T_f641e_row8_col1" class="data row8 col1" >47</td>
#       <td id="T_f641e_row8_col2" class="data row8 col2" >27</td>
#       <td id="T_f641e_row8_col3" class="data row8 col3" >234</td>
#       <td id="T_f641e_row8_col4" class="data row8 col4" >7</td>
#       <td id="T_f641e_row8_col5" class="data row8 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f641e_level0_row9" class="row_heading level0 row9" >Golf ball</th>
#       <td id="T_f641e_row9_col0" class="data row9 col0" >218</td>
#       <td id="T_f641e_row9_col1" class="data row9 col1" >41</td>
#       <td id="T_f641e_row9_col2" class="data row9 col2" >14</td>
#       <td id="T_f641e_row9_col3" class="data row9 col3" >140</td>
#       <td id="T_f641e_row9_col4" class="data row9 col4" >23</td>
#       <td id="T_f641e_row9_col5" class="data row9 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

from pathlib import Path
from collections import Counter
from typing import List, Optional
import pandas as pd
from IPython.display import display

# -------------------- 기본 경로/설정 --------------------
BASE = Path("/home/dw/ws_job_msislab/Golf_Project/data/for_study/20251017_merge_data")
IMAGES_DIR = BASE / "images"
LABELS_DIR = BASE / "labels"

SPLITS     = ["train", "val"]

DATE_MAP   = {"20250721": "0721", "20250725": "0725", "20250904": "0904" , "20250930": "0930" , "20250929": "0929"}
DATE_COLS  = ["0930","0929", "0904", "0725", "0721"]   # 날짜 순서
SUB_COLS   = ["Total"] + DATE_COLS      # 열 구조: Total, 0904, 0725, 0721

CLASS_ORDER = [
    "Divot", "Fixed_Divot", "Diseased_Grass", "Confused_Object",
    "Pole", "Sprinkler", "Drain", "Golf ball"
]
ROWS = ["Image", "bg"] + CLASS_ORDER

IMG_EXTS = {".jpg", ".jpeg", ".png", ".bmp", ".webp",
            ".JPG", ".JPEG", ".PNG", ".BMP", ".WEBP"}

# -------------------- 유틸 함수 --------------------
def detect_split(rel_path: Path) -> Optional[str]:
    for part in rel_path.parts:
        if part in SPLITS:
            return part
    return None

def detect_date(name: str) -> Optional[str]:
    for token, short in DATE_MAP.items():
        if token in name:
            return short
    return None

def read_label_ids(txt_path: Path) -> List[int]:
    try:
        if not txt_path.exists():
            return []
        txt = txt_path.read_text(encoding="utf-8", errors="ignore").strip()
        if not txt:
            return []
        ids = []
        for ln in txt.splitlines():
            ln = ln.strip()
            if not ln:
                continue
            first = ln.split()[0]
            try:
                cid = int(float(first))
            except Exception:
                continue
            ids.append(cid)
        return ids
    except Exception:
        return []

# -------------------- 메인 로직 --------------------
def build_split_by_date_with_totals() -> pd.DataFrame:
    # (split, date) 카운터
    table = {row: Counter({(sp, dt): 0 for sp in SPLITS for dt in DATE_COLS}) for row in ROWS}

    for img in IMAGES_DIR.rglob("*"):
        if not img.is_file() or img.suffix not in IMG_EXTS:
            continue

        name_lower = img.name.lower()

        # ✅ 전역 제외 규칙: dup 포함 or 'bg'가 2회 이상이면 완전 스킵
        if "dup" in name_lower or name_lower.count("bg") >= 2:
            continue

        rel   = img.relative_to(IMAGES_DIR)
        split = detect_split(rel)
        date  = detect_date(img.name)

        if split not in SPLITS or date not in DATE_COLS:
            continue

        # --- Image 행 ---
        table["Image"][(split, date)] += 1

        # --- 라벨 ---
        label_path = (LABELS_DIR / rel).with_suffix(".txt")
        label_ids = read_label_ids(label_path)

        # bg: 파일명에 "bg"가 '정확히 1번' 포함 & 라벨 비어있음
        if name_lower.count("bg") == 1 and len(label_ids) == 0:
            table["bg"][(split, date)] += 1

        # 클래스 카운트 (0~7)
        for cid in label_ids:
            if 0 <= cid <= 7:
                row = CLASS_ORDER[cid]
                table[row][(split, date)] += 1

    # ----- DataFrame 생성 -----
    columns = pd.MultiIndex.from_product([SPLITS, SUB_COLS])
    df = pd.DataFrame(index=ROWS, columns=columns, dtype="int64").fillna(0)

    for row in ROWS:
        for sp in SPLITS:
            for dt in DATE_COLS:
                df.loc[row, (sp, dt)] = table[row][(sp, dt)]
            # split-Total = 날짜 합계
            df.loc[row, (sp, "Total")] = sum(table[row][(sp, dt)] for dt in DATE_COLS)

    return df.astype(int)

# -------------------- 실행 & 출력 --------------------
df_sbdt = build_split_by_date_with_totals()

styled = (
    df_sbdt.style
    .set_properties(**{"text-align": "center"})
    .set_table_styles([dict(selector="th", props=[("text-align", "center")])])
)

display(styled)
# Out:
# <style type="text/css">
# #T_041da th {
#   text-align: center;
# }
# #T_041da_row0_col0, #T_041da_row0_col1, #T_041da_row0_col2, #T_041da_row0_col3, #T_041da_row0_col4, #T_041da_row0_col5, #T_041da_row0_col6, #T_041da_row0_col7, #T_041da_row0_col8, #T_041da_row0_col9, #T_041da_row0_col10, #T_041da_row0_col11, #T_041da_row1_col0, #T_041da_row1_col1, #T_041da_row1_col2, #T_041da_row1_col3, #T_041da_row1_col4, #T_041da_row1_col5, #T_041da_row1_col6, #T_041da_row1_col7, #T_041da_row1_col8, #T_041da_row1_col9, #T_041da_row1_col10, #T_041da_row1_col11, #T_041da_row2_col0, #T_041da_row2_col1, #T_041da_row2_col2, #T_041da_row2_col3, #T_041da_row2_col4, #T_041da_row2_col5, #T_041da_row2_col6, #T_041da_row2_col7, #T_041da_row2_col8, #T_041da_row2_col9, #T_041da_row2_col10, #T_041da_row2_col11, #T_041da_row3_col0, #T_041da_row3_col1, #T_041da_row3_col2, #T_041da_row3_col3, #T_041da_row3_col4, #T_041da_row3_col5, #T_041da_row3_col6, #T_041da_row3_col7, #T_041da_row3_col8, #T_041da_row3_col9, #T_041da_row3_col10, #T_041da_row3_col11, #T_041da_row4_col0, #T_041da_row4_col1, #T_041da_row4_col2, #T_041da_row4_col3, #T_041da_row4_col4, #T_041da_row4_col5, #T_041da_row4_col6, #T_041da_row4_col7, #T_041da_row4_col8, #T_041da_row4_col9, #T_041da_row4_col10, #T_041da_row4_col11, #T_041da_row5_col0, #T_041da_row5_col1, #T_041da_row5_col2, #T_041da_row5_col3, #T_041da_row5_col4, #T_041da_row5_col5, #T_041da_row5_col6, #T_041da_row5_col7, #T_041da_row5_col8, #T_041da_row5_col9, #T_041da_row5_col10, #T_041da_row5_col11, #T_041da_row6_col0, #T_041da_row6_col1, #T_041da_row6_col2, #T_041da_row6_col3, #T_041da_row6_col4, #T_041da_row6_col5, #T_041da_row6_col6, #T_041da_row6_col7, #T_041da_row6_col8, #T_041da_row6_col9, #T_041da_row6_col10, #T_041da_row6_col11, #T_041da_row7_col0, #T_041da_row7_col1, #T_041da_row7_col2, #T_041da_row7_col3, #T_041da_row7_col4, #T_041da_row7_col5, #T_041da_row7_col6, #T_041da_row7_col7, #T_041da_row7_col8, #T_041da_row7_col9, #T_041da_row7_col10, #T_041da_row7_col11, #T_041da_row8_col0, #T_041da_row8_col1, #T_041da_row8_col2, #T_041da_row8_col3, #T_041da_row8_col4, #T_041da_row8_col5, #T_041da_row8_col6, #T_041da_row8_col7, #T_041da_row8_col8, #T_041da_row8_col9, #T_041da_row8_col10, #T_041da_row8_col11, #T_041da_row9_col0, #T_041da_row9_col1, #T_041da_row9_col2, #T_041da_row9_col3, #T_041da_row9_col4, #T_041da_row9_col5, #T_041da_row9_col6, #T_041da_row9_col7, #T_041da_row9_col8, #T_041da_row9_col9, #T_041da_row9_col10, #T_041da_row9_col11 {
#   text-align: center;
# }
# </style>
# <table id="T_041da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_041da_level0_col0" class="col_heading level0 col0" colspan="6">train</th>
#       <th id="T_041da_level0_col6" class="col_heading level0 col6" colspan="6">val</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_041da_level1_col0" class="col_heading level1 col0" >Total</th>
#       <th id="T_041da_level1_col1" class="col_heading level1 col1" >0930</th>
#       <th id="T_041da_level1_col2" class="col_heading level1 col2" >0929</th>
#       <th id="T_041da_level1_col3" class="col_heading level1 col3" >0904</th>
#       <th id="T_041da_level1_col4" class="col_heading level1 col4" >0725</th>
#       <th id="T_041da_level1_col5" class="col_heading level1 col5" >0721</th>
#       <th id="T_041da_level1_col6" class="col_heading level1 col6" >Total</th>
#       <th id="T_041da_level1_col7" class="col_heading level1 col7" >0930</th>
#       <th id="T_041da_level1_col8" class="col_heading level1 col8" >0929</th>
#       <th id="T_041da_level1_col9" class="col_heading level1 col9" >0904</th>
#       <th id="T_041da_level1_col10" class="col_heading level1 col10" >0725</th>
#       <th id="T_041da_level1_col11" class="col_heading level1 col11" >0721</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_041da_level0_row0" class="row_heading level0 row0" >Image</th>
#       <td id="T_041da_row0_col0" class="data row0 col0" >4701</td>
#       <td id="T_041da_row0_col1" class="data row0 col1" >698</td>
#       <td id="T_041da_row0_col2" class="data row0 col2" >320</td>
#       <td id="T_041da_row0_col3" class="data row0 col3" >2798</td>
#       <td id="T_041da_row0_col4" class="data row0 col4" >385</td>
#       <td id="T_041da_row0_col5" class="data row0 col5" >500</td>
#       <td id="T_041da_row0_col6" class="data row0 col6" >666</td>
#       <td id="T_041da_row0_col7" class="data row0 col7" >94</td>
#       <td id="T_041da_row0_col8" class="data row0 col8" >37</td>
#       <td id="T_041da_row0_col9" class="data row0 col9" >417</td>
#       <td id="T_041da_row0_col10" class="data row0 col10" >55</td>
#       <td id="T_041da_row0_col11" class="data row0 col11" >63</td>
#     </tr>
#     <tr>
#       <th id="T_041da_level0_row1" class="row_heading level0 row1" >bg</th>
#       <td id="T_041da_row1_col0" class="data row1 col0" >119</td>
#       <td id="T_041da_row1_col1" class="data row1 col1" >26</td>
#       <td id="T_041da_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_041da_row1_col3" class="data row1 col3" >25</td>
#       <td id="T_041da_row1_col4" class="data row1 col4" >38</td>
#       <td id="T_041da_row1_col5" class="data row1 col5" >30</td>
#       <td id="T_041da_row1_col6" class="data row1 col6" >13</td>
#       <td id="T_041da_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_041da_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_041da_row1_col9" class="data row1 col9" >4</td>
#       <td id="T_041da_row1_col10" class="data row1 col10" >7</td>
#       <td id="T_041da_row1_col11" class="data row1 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_041da_level0_row2" class="row_heading level0 row2" >Divot</th>
#       <td id="T_041da_row2_col0" class="data row2 col0" >5238</td>
#       <td id="T_041da_row2_col1" class="data row2 col1" >1367</td>
#       <td id="T_041da_row2_col2" class="data row2 col2" >369</td>
#       <td id="T_041da_row2_col3" class="data row2 col3" >2848</td>
#       <td id="T_041da_row2_col4" class="data row2 col4" >171</td>
#       <td id="T_041da_row2_col5" class="data row2 col5" >483</td>
#       <td id="T_041da_row2_col6" class="data row2 col6" >757</td>
#       <td id="T_041da_row2_col7" class="data row2 col7" >178</td>
#       <td id="T_041da_row2_col8" class="data row2 col8" >25</td>
#       <td id="T_041da_row2_col9" class="data row2 col9" >457</td>
#       <td id="T_041da_row2_col10" class="data row2 col10" >25</td>
#       <td id="T_041da_row2_col11" class="data row2 col11" >72</td>
#     </tr>
#     <tr>
#       <th id="T_041da_level0_row3" class="row_heading level0 row3" >Fixed_Divot</th>
#       <td id="T_041da_row3_col0" class="data row3 col0" >7452</td>
#       <td id="T_041da_row3_col1" class="data row3 col1" >1932</td>
#       <td id="T_041da_row3_col2" class="data row3 col2" >1021</td>
#       <td id="T_041da_row3_col3" class="data row3 col3" >3530</td>
#       <td id="T_041da_row3_col4" class="data row3 col4" >485</td>
#       <td id="T_041da_row3_col5" class="data row3 col5" >484</td>
#       <td id="T_041da_row3_col6" class="data row3 col6" >1090</td>
#       <td id="T_041da_row3_col7" class="data row3 col7" >247</td>
#       <td id="T_041da_row3_col8" class="data row3 col8" >150</td>
#       <td id="T_041da_row3_col9" class="data row3 col9" >563</td>
#       <td id="T_041da_row3_col10" class="data row3 col10" >57</td>
#       <td id="T_041da_row3_col11" class="data row3 col11" >73</td>
#     </tr>
#     <tr>
#       <th id="T_041da_level0_row4" class="row_heading level0 row4" >Diseased_Grass</th>
#       <td id="T_041da_row4_col0" class="data row4 col0" >585</td>
#       <td id="T_041da_row4_col1" class="data row4 col1" >53</td>
#       <td id="T_041da_row4_col2" class="data row4 col2" >46</td>
#       <td id="T_041da_row4_col3" class="data row4 col3" >448</td>
#       <td id="T_041da_row4_col4" class="data row4 col4" >18</td>
#       <td id="T_041da_row4_col5" class="data row4 col5" >20</td>
#       <td id="T_041da_row4_col6" class="data row4 col6" >94</td>
#       <td id="T_041da_row4_col7" class="data row4 col7" >14</td>

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
# TEST
from pathlib import Path
from collections import Counter
from typing import List, Optional
import pandas as pd
from IPython.display import display

# -------------------- 기본 경로/설정 --------------------
BASE = Path("/home/dw/ws_job_msislab/Golf_Project/data/for_test/test_20251013")
IMAGES_DIR = BASE / "images"
LABELS_DIR = BASE / "labels"

SPLITS     = ["test"]

DATE_MAP   = {"20250904": "0904" , "20250930": "0930"}
DATE_COLS  = ["0930", "0904"]   # 날짜 순서
SUB_COLS   = ["Total"] + DATE_COLS      # 열 구조: Total, 0904, 0725, 0721

CLASS_ORDER = [
    "Divot", "Fixed_Divot", "Diseased_Grass", "Confused_Object",
    "Pole", "Sprinkler", "Drain", "Golf ball"
]
ROWS = ["Image", "bg"] + CLASS_ORDER

IMG_EXTS = {".jpg", ".jpeg", ".png", ".bmp", ".webp",
            ".JPG", ".JPEG", ".PNG", ".BMP", ".WEBP"}

# -------------------- 유틸 함수 --------------------
def detect_split(rel_path: Path) -> Optional[str]:
    for part in rel_path.parts:
        if part in SPLITS:
            return part
    return None

def detect_date(name: str) -> Optional[str]:
    for token, short in DATE_MAP.items():
        if token in name:
            return short
    return None

def read_label_ids(txt_path: Path) -> List[int]:
    try:
        if not txt_path.exists():
            return []
        txt = txt_path.read_text(encoding="utf-8", errors="ignore").strip()
        if not txt:
            return []
        ids = []
        for ln in txt.splitlines():
            ln = ln.strip()
            if not ln:
                continue
            first = ln.split()[0]
            try:
                cid = int(float(first))
            except Exception:
                continue
            ids.append(cid)
        return ids
    except Exception:
        return []

# -------------------- 메인 로직 --------------------
def build_split_by_date_with_totals() -> pd.DataFrame:
    # (split, date) 카운터
    table = {row: Counter({(sp, dt): 0 for sp in SPLITS for dt in DATE_COLS}) for row in ROWS}

    for img in IMAGES_DIR.rglob("*"):
        if not img.is_file() or img.suffix not in IMG_EXTS:
            continue

        name_lower = img.name.lower()

        # ✅ 전역 제외 규칙: dup 포함 or 'bg'가 2회 이상이면 완전 스킵
        if "dup" in name_lower or name_lower.count("bg") >= 2:
            continue

        rel   = img.relative_to(IMAGES_DIR)
        split = detect_split(rel)
        date  = detect_date(img.name)

        if split not in SPLITS or date not in DATE_COLS:
            continue

        # --- Image 행 ---
        table["Image"][(split, date)] += 1

        # --- 라벨 ---
        label_path = (LABELS_DIR / rel).with_suffix(".txt")
        label_ids = read_label_ids(label_path)

        # bg: 파일명에 "bg"가 '정확히 1번' 포함 & 라벨 비어있음
        if name_lower.count("bg") == 1 and len(label_ids) == 0:
            table["bg"][(split, date)] += 1

        # 클래스 카운트 (0~7)
        for cid in label_ids:
            if 0 <= cid <= 7:
                row = CLASS_ORDER[cid]
                table[row][(split, date)] += 1

    # ----- DataFrame 생성 -----
    columns = pd.MultiIndex.from_product([SPLITS, SUB_COLS])
    df = pd.DataFrame(index=ROWS, columns=columns, dtype="int64").fillna(0)

    for row in ROWS:
        for sp in SPLITS:
            for dt in DATE_COLS:
                df.loc[row, (sp, dt)] = table[row][(sp, dt)]
            # split-Total = 날짜 합계
            df.loc[row, (sp, "Total")] = sum(table[row][(sp, dt)] for dt in DATE_COLS)

    return df.astype(int)

# -------------------- 실행 & 출력 --------------------
df_sbdt = build_split_by_date_with_totals()

styled = (
    df_sbdt.style
    .set_properties(**{"text-align": "center"})
    .set_table_styles([dict(selector="th", props=[("text-align", "center")])])
)

display(styled)
# Out:
# <style type="text/css">
# #T_58d3b th {
#   text-align: center;
# }
# #T_58d3b_row0_col0, #T_58d3b_row0_col1, #T_58d3b_row0_col2, #T_58d3b_row1_col0, #T_58d3b_row1_col1, #T_58d3b_row1_col2, #T_58d3b_row2_col0, #T_58d3b_row2_col1, #T_58d3b_row2_col2, #T_58d3b_row3_col0, #T_58d3b_row3_col1, #T_58d3b_row3_col2, #T_58d3b_row4_col0, #T_58d3b_row4_col1, #T_58d3b_row4_col2, #T_58d3b_row5_col0, #T_58d3b_row5_col1, #T_58d3b_row5_col2, #T_58d3b_row6_col0, #T_58d3b_row6_col1, #T_58d3b_row6_col2, #T_58d3b_row7_col0, #T_58d3b_row7_col1, #T_58d3b_row7_col2, #T_58d3b_row8_col0, #T_58d3b_row8_col1, #T_58d3b_row8_col2, #T_58d3b_row9_col0, #T_58d3b_row9_col1, #T_58d3b_row9_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_58d3b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58d3b_level0_col0" class="col_heading level0 col0" colspan="3">test</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_58d3b_level1_col0" class="col_heading level1 col0" >Total</th>
#       <th id="T_58d3b_level1_col1" class="col_heading level1 col1" >0930</th>
#       <th id="T_58d3b_level1_col2" class="col_heading level1 col2" >0904</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58d3b_level0_row0" class="row_heading level0 row0" >Image</th>
#       <td id="T_58d3b_row0_col0" class="data row0 col0" >426</td>
#       <td id="T_58d3b_row0_col1" class="data row0 col1" >100</td>
#       <td id="T_58d3b_row0_col2" class="data row0 col2" >326</td>
#     </tr>
#     <tr>
#       <th id="T_58d3b_level0_row1" class="row_heading level0 row1" >bg</th>
#       <td id="T_58d3b_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_58d3b_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_58d3b_row1_col2" class="data row1 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_58d3b_level0_row2" class="row_heading level0 row2" >Divot</th>
#       <td id="T_58d3b_row2_col0" class="data row2 col0" >588</td>
#       <td id="T_58d3b_row2_col1" class="data row2 col1" >182</td>
#       <td id="T_58d3b_row2_col2" class="data row2 col2" >406</td>
#     </tr>
#     <tr>
#       <th id="T_58d3b_level0_row3" class="row_heading level0 row3" >Fixed_Divot</th>
#       <td id="T_58d3b_row3_col0" class="data row3 col0" >809</td>
#       <td id="T_58d3b_row3_col1" class="data row3 col1" >296</td>
#       <td id="T_58d3b_row3_col2" class="data row3 col2" >513</td>
#     </tr>
#     <tr>
#       <th id="T_58d3b_level0_row4" class="row_heading level0 row4" >Diseased_Grass</th>
#       <td id="T_58d3b_row4_col0" class="data row4 col0" >80</td>
#       <td id="T_58d3b_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_58d3b_row4_col2" class="data row4 col2" >72</td>
#     </tr>
#     <tr>
#       <th id="T_58d3b_level0_row5" class="row_heading level0 row5" >Confused_Object</th>
#       <td id="T_58d3b_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_58d3b_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_58d3b_row5_col2" class="data row5 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_58d3b_level0_row6" class="row_heading level0 row6" >Pole</th>
#       <td id="T_58d3b_row6_col0" class="data row6 col0" >11</td>
#       <td id="T_58d3b_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_58d3b_row6_col2" class="data row6 col2" >11</td>
#     </tr>
#     <tr>
#       <th id="T_58d3b_level0_row7" class="row_heading level0 row7" >Sprinkler</th>
#       <td id="T_58d3b_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_58d3b_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_58d3b_row7_col2" class="data row7 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_58d3b_level0_row8" class="row_heading level0 row8" >Drain</th>
#       <td id="T_58d3b_row8_col0" class="data row8 col0" >48</td>
#       <td id="T_58d3b_row8_col1" class="data row8 col1" >8</td>
#       <td id="T_58d3b_row8_col2" class="data row8 col2" >40</td>
#     </tr>
#     <tr>
#       <th id="T_58d3b_level0_row9" class="row_heading level0 row9" >Golf ball</th>
#       <td id="T_58d3b_row9_col0" class="data row9 col0" >21</td>
#       <td id="T_58d3b_row9_col1" class="data row9 col1" >6</td>
#       <td id="T_58d3b_row9_col2" class="data row9 col2" >15</td>
#     </tr>
#   </tbody>
# </table>

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

from pathlib import Path
from collections import Counter
from typing import List, Optional, Tuple
import pandas as pd
from IPython.display import display
from itertools import product

# -------------------- 기본 경로/설정 --------------------
BASE = Path("/home/dw/ws_job_msislab/Golf_Project/data/for_study/20251017_merge_data")
IMAGES_DIR = BASE / "images"
LABELS_DIR = BASE / "labels"

DATE_MAP   = {"20250721": "0721", "20250725": "0725", "20250904": "0904" , "20250930": "0930" , "20250929": "0929"}
DATE_COLS  = ["0930", "0929", "0904", "0725", "0721"]   # 날짜 순서
SUB_COLS   = ["Total"] + DATE_COLS
AUG_COLS   = ["orig", "aug"]

CLASS_ORDER = [
    "Divot", "Fixed_Divot", "Diseased_Grass", "Confused_Object",
    "Pole", "Sprinkler", "Drain", "Golf ball"
]
ROWS = ["Image", "bg"] + CLASS_ORDER

IMG_EXTS = {".jpg", ".jpeg", ".png", ".bmp", ".webp",
            ".JPG", ".JPEG", ".PNG", ".BMP", ".WEBP"}

# -------------------- 유틸 함수 --------------------
def detect_date_from_name(name: str) -> Optional[str]:
    low = name.lower()
    for token, short in DATE_MAP.items():
        if token in low:
            return short
    return None

def read_label_ids(txt_path: Path) -> List[int]:
    try:
        if not txt_path.exists():
            return []
        txt = txt_path.read_text(encoding="utf-8", errors="ignore").strip()
        if not txt:
            return []
        ids = []
        for ln in txt.splitlines():
            ln = ln.strip()
            if not ln:
                continue
            first = ln.split()[0]
            try:
                cid = int(float(first))
            except Exception:
                continue
            ids.append(cid)
        return ids
    except Exception:
        return []

def is_augmented(name_lower: str) -> bool:
    """증강 판단 규칙: dup 포함 OR 'bg'가 2회 이상"""
    return ("dup" in name_lower) or (name_lower.count("bg") >= 2)

def is_original(name_lower: str) -> bool:
    """원본 판단 규칙: dup 없음 AND 'bg'가 0~1회"""
    return ("dup" not in name_lower) and (name_lower.count("bg") <= 1)

# -------------------- 메인 로직 --------------------
def build_train_only_table() -> pd.DataFrame:
    # (date, augflag) 카운터 준비
    keys = list(product(DATE_COLS, AUG_COLS))
    def empty_counter():
        return Counter({k: 0 for k in keys})

    table = {row: empty_counter() for row in ROWS}

    train_dir = IMAGES_DIR / "train"
    for img in train_dir.rglob("*"):   # ✅ train만 순회
        if not img.is_file() or img.suffix not in IMG_EXTS:
            continue

        name = img.name
        low  = name.lower()

        date = detect_date_from_name(name)
        if date not in DATE_COLS:
            continue

        # --- 증강 여부 판단 ---
        if is_augmented(low):
            augflag = "aug"
        elif is_original(low):
            augflag = "orig"
        else:
            # 규칙에 애매하게 걸리면(이론상 없겠지만) 스킵
            continue

        # --- Image 행 ---
        table["Image"][(date, augflag)] += 1

        # --- 라벨 경로 (train 기준으로 상대경로 맞추기) ---
        rel_from_train = img.relative_to(train_dir)                 # e.g. 0904/xxx.jpg
        label_path = (LABELS_DIR / "train" / rel_from_train).with_suffix(".txt")
        label_ids = read_label_ids(label_path)

        # bg: 라벨 비었고 파일명에 'bg'가 1회 이상(원본/증강 모두 카운트)
        if len(label_ids) == 0 and ("bg" in low):
            table["bg"][(date, augflag)] += 1

        # 클래스 카운트 (0~7)
        for cid in label_ids:
            if 0 <= cid <= 7:
                row = CLASS_ORDER[cid]
                table[row][(date, augflag)] += 1

    # ----- DataFrame: 멀티컬럼( train / Total·날짜 / orig·aug ) -----
    columns = pd.MultiIndex.from_product([["train"], SUB_COLS, AUG_COLS])
    df = pd.DataFrame(index=ROWS, columns=columns, dtype="int64").fillna(0)

    for row in ROWS:
        # 날짜별 값
        for dt in DATE_COLS:
            for ag in AUG_COLS:
                df.loc[row, ("train", dt, ag)] = table[row][(dt, ag)]
        # Total = 날짜 합계
        for ag in AUG_COLS:
            df.loc[row, ("train", "Total", ag)] = sum(table[row][(d, ag)] for d in DATE_COLS)

    return df.astype(int)

# -------------------- 실행 & 출력 --------------------
df_train = build_train_only_table()

styled = (
    df_train.style
    .set_properties(**{"text-align": "center"})
    .set_table_styles([dict(selector="th", props=[("text-align", "center")])])
)

display(styled)
# Out:
# <style type="text/css">
# #T_a9602 th {
#   text-align: center;
# }
# #T_a9602_row0_col0, #T_a9602_row0_col1, #T_a9602_row0_col2, #T_a9602_row0_col3, #T_a9602_row0_col4, #T_a9602_row0_col5, #T_a9602_row0_col6, #T_a9602_row0_col7, #T_a9602_row0_col8, #T_a9602_row0_col9, #T_a9602_row0_col10, #T_a9602_row0_col11, #T_a9602_row1_col0, #T_a9602_row1_col1, #T_a9602_row1_col2, #T_a9602_row1_col3, #T_a9602_row1_col4, #T_a9602_row1_col5, #T_a9602_row1_col6, #T_a9602_row1_col7, #T_a9602_row1_col8, #T_a9602_row1_col9, #T_a9602_row1_col10, #T_a9602_row1_col11, #T_a9602_row2_col0, #T_a9602_row2_col1, #T_a9602_row2_col2, #T_a9602_row2_col3, #T_a9602_row2_col4, #T_a9602_row2_col5, #T_a9602_row2_col6, #T_a9602_row2_col7, #T_a9602_row2_col8, #T_a9602_row2_col9, #T_a9602_row2_col10, #T_a9602_row2_col11, #T_a9602_row3_col0, #T_a9602_row3_col1, #T_a9602_row3_col2, #T_a9602_row3_col3, #T_a9602_row3_col4, #T_a9602_row3_col5, #T_a9602_row3_col6, #T_a9602_row3_col7, #T_a9602_row3_col8, #T_a9602_row3_col9, #T_a9602_row3_col10, #T_a9602_row3_col11, #T_a9602_row4_col0, #T_a9602_row4_col1, #T_a9602_row4_col2, #T_a9602_row4_col3, #T_a9602_row4_col4, #T_a9602_row4_col5, #T_a9602_row4_col6, #T_a9602_row4_col7, #T_a9602_row4_col8, #T_a9602_row4_col9, #T_a9602_row4_col10, #T_a9602_row4_col11, #T_a9602_row5_col0, #T_a9602_row5_col1, #T_a9602_row5_col2, #T_a9602_row5_col3, #T_a9602_row5_col4, #T_a9602_row5_col5, #T_a9602_row5_col6, #T_a9602_row5_col7, #T_a9602_row5_col8, #T_a9602_row5_col9, #T_a9602_row5_col10, #T_a9602_row5_col11, #T_a9602_row6_col0, #T_a9602_row6_col1, #T_a9602_row6_col2, #T_a9602_row6_col3, #T_a9602_row6_col4, #T_a9602_row6_col5, #T_a9602_row6_col6, #T_a9602_row6_col7, #T_a9602_row6_col8, #T_a9602_row6_col9, #T_a9602_row6_col10, #T_a9602_row6_col11, #T_a9602_row7_col0, #T_a9602_row7_col1, #T_a9602_row7_col2, #T_a9602_row7_col3, #T_a9602_row7_col4, #T_a9602_row7_col5, #T_a9602_row7_col6, #T_a9602_row7_col7, #T_a9602_row7_col8, #T_a9602_row7_col9, #T_a9602_row7_col10, #T_a9602_row7_col11, #T_a9602_row8_col0, #T_a9602_row8_col1, #T_a9602_row8_col2, #T_a9602_row8_col3, #T_a9602_row8_col4, #T_a9602_row8_col5, #T_a9602_row8_col6, #T_a9602_row8_col7, #T_a9602_row8_col8, #T_a9602_row8_col9, #T_a9602_row8_col10, #T_a9602_row8_col11, #T_a9602_row9_col0, #T_a9602_row9_col1, #T_a9602_row9_col2, #T_a9602_row9_col3, #T_a9602_row9_col4, #T_a9602_row9_col5, #T_a9602_row9_col6, #T_a9602_row9_col7, #T_a9602_row9_col8, #T_a9602_row9_col9, #T_a9602_row9_col10, #T_a9602_row9_col11 {
#   text-align: center;
# }
# </style>
# <table id="T_a9602">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9602_level0_col0" class="col_heading level0 col0" colspan="12">train</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_a9602_level1_col0" class="col_heading level1 col0" colspan="2">Total</th>
#       <th id="T_a9602_level1_col2" class="col_heading level1 col2" colspan="2">0930</th>
#       <th id="T_a9602_level1_col4" class="col_heading level1 col4" colspan="2">0929</th>
#       <th id="T_a9602_level1_col6" class="col_heading level1 col6" colspan="2">0904</th>
#       <th id="T_a9602_level1_col8" class="col_heading level1 col8" colspan="2">0725</th>
#       <th id="T_a9602_level1_col10" class="col_heading level1 col10" colspan="2">0721</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_a9602_level2_col0" class="col_heading level2 col0" >orig</th>
#       <th id="T_a9602_level2_col1" class="col_heading level2 col1" >aug</th>
#       <th id="T_a9602_level2_col2" class="col_heading level2 col2" >orig</th>
#       <th id="T_a9602_level2_col3" class="col_heading level2 col3" >aug</th>
#       <th id="T_a9602_level2_col4" class="col_heading level2 col4" >orig</th>
#       <th id="T_a9602_level2_col5" class="col_heading level2 col5" >aug</th>
#       <th id="T_a9602_level2_col6" class="col_heading level2 col6" >orig</th>
#       <th id="T_a9602_level2_col7" class="col_heading level2 col7" >aug</th>
#       <th id="T_a9602_level2_col8" class="col_heading level2 col8" >orig</th>
#       <th id="T_a9602_level2_col9" class="col_heading level2 col9" >aug</th>
#       <th id="T_a9602_level2_col10" class="col_heading level2 col10" >orig</th>
#       <th id="T_a9602_level2_col11" class="col_heading level2 col11" >aug</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9602_level0_row0" class="row_heading level0 row0" >Image</th>
#       <td id="T_a9602_row0_col0" class="data row0 col0" >4701</td>
#       <td id="T_a9602_row0_col1" class="data row0 col1" >4252</td>
#       <td id="T_a9602_row0_col2" class="data row0 col2" >698</td>
#       <td id="T_a9602_row0_col3" class="data row0 col3" >774</td>
#       <td id="T_a9602_row0_col4" class="data row0 col4" >320</td>
#       <td id="T_a9602_row0_col5" class="data row0 col5" >342</td>
#       <td id="T_a9602_row0_col6" class="data row0 col6" >2798</td>
#       <td id="T_a9602_row0_col7" class="data row0 col7" >2405</td>
#       <td id="T_a9602_row0_col8" class="data row0 col8" >385</td>
#       <td id="T_a9602_row0_col9" class="data row0 col9" >297</td>
#       <td id="T_a9602_row0_col10" class="data row0 col10" >500</td>
#       <td id="T_a9602_row0_col11" class="data row0 col11" >434</td>
#     </tr>
#     <tr>
#       <th id="T_a9602_level0_row1" class="row_heading level0 row1" >bg</th>
#       <td id="T_a9602_row1_col0" class="data row1 col0" >119</td>
#       <td id="T_a9602_row1_col1" class="data row1 col1" >238</td>
#       <td id="T_a9602_row1_col2" class="data row1 col2" >26</td>
#       <td id="T_a9602_row1_col3" class="data row1 col3" >52</td>
#       <td id="T_a9602_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_a9602_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_a9602_row1_col6" class="data row1 col6" >25</td>
#       <td id="T_a9602_row1_col7" class="data row1 col7" >50</td>
#       <td id="T_a9602_row1_col8" class="data row1 col8" >38</td>
#       <td id="T_a9602_row1_col9" class="data row1 col9" >76</td>
#       <td id="T_a9602_row1_col10" class="data row1 col10" >30</td>
#       <td id="T_a9602_row1_col11" class="data row1 col11" >60</td>
#     </tr>
#     <tr>
#       <th id="T_a9602_level0_row2" class="row_heading level0 row2" >Divot</th>
#       <td id="T_a9602_row2_col0" class="data row2 col0" >5238</td>
#       <td id="T_a9602_row2_col1" class="data row2 col1" >5576</td>
#       <td id="T_a9602_row2_col2" class="data row2 col2" >1367</td>
#       <td id="T_a9602_row2_col3" class="data row2 col3" >1436</td>
#       <td id="T_a9602_row2_col4" class="data row2 col4" >369</td>
#       <td id="T_a9602_row2_col5" class="data row2 col5" >371</td>
#       <td id="T_a9602_row2_col6" class="data row2 col6" >2848</td>
#       <td id="T_a9602_row2_col7" class="data row2 col7" >3111</td>
#       <td id="T_a9602_row2_col8" class="data row2 col8" >171</td>
#       <td id="T_a9602_row2_col9" class="data row2 col9" >181</td>
#       <td id="T_a9602_row2_col10" class="data row2 col10" >483</td>
#       <td id="T_a9602_row2_col11" class="data row2 col11" >477</td>
#     </tr>
#     <tr>
#       <th id="T_a9602_level0_row3" class="row_heading level0 row3" >Fixed_Divot</th>
#       <td id="T_a9602_row3_col0" class="data row3 col0" >7452</td>
#       <td id="T_a9602_row3_col1" class="data row3 col1" >6393</td>
#       <td id="T_a9602_row3_col2" class="data row3 col2" >1932</td>
#       <td id="T_a9602_row3_col3" class="data row3 col3" >2118</td>
#       <td id="T_a9602_row3_col4" class="data row3 col4" >1021</td>
#       <td id="T_a9602_row3_col5" class="data row3 col5" >984</td>
#       <td id="T_a9602_row3_col6" class="data row3 col6" >3530</td>
#       <td id="T_a9602_row3_col7" class="data row3 col7" >2733</td>
#       <td id="T_a9602_row3_col8" class="data row3 col8" >485</td>
#       <td id="T_a9602_row3_col9" class="data row3 col9" >245</td>
#       <td id="T_a9602_row3_col10" class="data row3 col10" >484</td>
#       <td id="T_a9602_row3_col11" class="data row3 col11" >313</td>
#     </tr>
#     <tr>
#       <th id="T_a9602_level0_row4" class="row_heading level0 row4" >Diseased_Grass</th>

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

from pathlib import Path
from collections import Counter
from typing import List, Optional
import pandas as pd
from IPython.display import display

# -------------------- 기본 경로 --------------------
BASE = Path("/home/dw/ws_job_msislab/Golf_Project/data/for_study/20251107_merge_data")
IMAGES_DIR = BASE / "images"
LABELS_DIR = BASE / "labels"

SPLITS = ["train", "val"]
COLS   = ["Total", "train", "val"]

CLASS_ORDER = [
    "Divot", "Fixed_Divot", "Diseased_Grass", "Confused_Object",
    "Pole", "Sprinkler", "Drain", "Golf ball"
]
ROWS = ["Image", "bg"] + CLASS_ORDER

IMG_EXTS = {".jpg", ".jpeg", ".png", ".bmp", ".webp",
            ".JPG", ".JPEG", ".PNG", ".BMP", ".WEBP"}

# -------------------- 유틸 함수 --------------------
def detect_split(rel_path: Path) -> Optional[str]:
    for part in rel_path.parts:
        if part in SPLITS:
            return part
    return None

def read_label_ids(txt_path: Path) -> List[int]:
    try:
        if not txt_path.exists():
            return []
        txt = txt_path.read_text(encoding="utf-8", errors="ignore").strip()
        if not txt:
            return []
        ids = []
        for ln in txt.splitlines():
            ln = ln.strip()
            if not ln:
                continue
            first = ln.split()[0]
            try:
                cid = int(float(first))
            except Exception:
                continue
            ids.append(cid)
        return ids
    except Exception:
        return []

# -------------------- 메인 로직 --------------------
def build_split_totals() -> pd.DataFrame:
    table = {row: Counter({c: 0 for c in COLS}) for row in ROWS}

    for img in IMAGES_DIR.rglob("*"):
        if not img.is_file() or img.suffix not in IMG_EXTS:
            continue

        rel   = img.relative_to(IMAGES_DIR)
        split = detect_split(rel)
        if split not in SPLITS:
            continue

        # === Image ===
        table["Image"][split] += 1
        table["Image"]["Total"] += 1

        # === 라벨 ===
        label_path = (LABELS_DIR / rel).with_suffix(".txt")
        label_ids = read_label_ids(label_path)

        # bg: 라벨 비었고 'bg' 포함 시
        if len(label_ids) == 0 and ("bg" in img.name.lower()):
            table["bg"][split] += 1
            table["bg"]["Total"] += 1

        # 클래스 카운트
        for cid in label_ids:
            if 0 <= cid <= 7:
                row = CLASS_ORDER[cid]
                table[row][split] += 1
                table[row]["Total"] += 1

    df = pd.DataFrame({c: [table[row][c] for row in ROWS] for c in COLS}, index=ROWS).astype(int)
    return df

# -------------------- 실행 & 출력 --------------------
df_counts = build_split_totals()

styled = (
    df_counts.style
    .set_properties(**{"text-align": "center"})
    .set_table_styles([dict(selector="th", props=[("text-align", "center")])])
)

display(styled)
# Out:
# <style type="text/css">
# #T_e44b1 th {
#   text-align: center;
# }
# #T_e44b1_row0_col0, #T_e44b1_row0_col1, #T_e44b1_row0_col2, #T_e44b1_row1_col0, #T_e44b1_row1_col1, #T_e44b1_row1_col2, #T_e44b1_row2_col0, #T_e44b1_row2_col1, #T_e44b1_row2_col2, #T_e44b1_row3_col0, #T_e44b1_row3_col1, #T_e44b1_row3_col2, #T_e44b1_row4_col0, #T_e44b1_row4_col1, #T_e44b1_row4_col2, #T_e44b1_row5_col0, #T_e44b1_row5_col1, #T_e44b1_row5_col2, #T_e44b1_row6_col0, #T_e44b1_row6_col1, #T_e44b1_row6_col2, #T_e44b1_row7_col0, #T_e44b1_row7_col1, #T_e44b1_row7_col2, #T_e44b1_row8_col0, #T_e44b1_row8_col1, #T_e44b1_row8_col2, #T_e44b1_row9_col0, #T_e44b1_row9_col1, #T_e44b1_row9_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_e44b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e44b1_level0_col0" class="col_heading level0 col0" >Total</th>
#       <th id="T_e44b1_level0_col1" class="col_heading level0 col1" >train</th>
#       <th id="T_e44b1_level0_col2" class="col_heading level0 col2" >val</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e44b1_level0_row0" class="row_heading level0 row0" >Image</th>
#       <td id="T_e44b1_row0_col0" class="data row0 col0" >10573</td>
#       <td id="T_e44b1_row0_col1" class="data row0 col1" >9819</td>
#       <td id="T_e44b1_row0_col2" class="data row0 col2" >754</td>
#     </tr>
#     <tr>
#       <th id="T_e44b1_level0_row1" class="row_heading level0 row1" >bg</th>
#       <td id="T_e44b1_row1_col0" class="data row1 col0" >557</td>
#       <td id="T_e44b1_row1_col1" class="data row1 col1" >536</td>
#       <td id="T_e44b1_row1_col2" class="data row1 col2" >21</td>
#     </tr>
#     <tr>
#       <th id="T_e44b1_level0_row2" class="row_heading level0 row2" >Divot</th>
#       <td id="T_e44b1_row2_col0" class="data row2 col0" >12583</td>
#       <td id="T_e44b1_row2_col1" class="data row2 col1" >11809</td>
#       <td id="T_e44b1_row2_col2" class="data row2 col2" >774</td>
#     </tr>
#     <tr>
#       <th id="T_e44b1_level0_row3" class="row_heading level0 row3" >Fixed_Divot</th>
#       <td id="T_e44b1_row3_col0" class="data row3 col0" >15462</td>
#       <td id="T_e44b1_row3_col1" class="data row3 col1" >14189</td>
#       <td id="T_e44b1_row3_col2" class="data row3 col2" >1273</td>
#     </tr>
#     <tr>
#       <th id="T_e44b1_level0_row4" class="row_heading level0 row4" >Diseased_Grass</th>
#       <td id="T_e44b1_row4_col0" class="data row4 col0" >1725</td>
#       <td id="T_e44b1_row4_col1" class="data row4 col1" >1586</td>
#       <td id="T_e44b1_row4_col2" class="data row4 col2" >139</td>
#     </tr>
#     <tr>
#       <th id="T_e44b1_level0_row5" class="row_heading level0 row5" >Confused_Object</th>
#       <td id="T_e44b1_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_e44b1_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_e44b1_row5_col2" class="data row5 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e44b1_level0_row6" class="row_heading level0 row6" >Pole</th>
#       <td id="T_e44b1_row6_col0" class="data row6 col0" >323</td>
#       <td id="T_e44b1_row6_col1" class="data row6 col1" >300</td>
#       <td id="T_e44b1_row6_col2" class="data row6 col2" >23</td>
#     </tr>
#     <tr>
#       <th id="T_e44b1_level0_row7" class="row_heading level0 row7" >Sprinkler</th>
#       <td id="T_e44b1_row7_col0" class="data row7 col0" >235</td>
#       <td id="T_e44b1_row7_col1" class="data row7 col1" >229</td>
#       <td id="T_e44b1_row7_col2" class="data row7 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e44b1_level0_row8" class="row_heading level0 row8" >Drain</th>
#       <td id="T_e44b1_row8_col0" class="data row8 col0" >759</td>
#       <td id="T_e44b1_row8_col1" class="data row8 col1" >723</td>
#       <td id="T_e44b1_row8_col2" class="data row8 col2" >36</td>
#     </tr>
#     <tr>
#       <th id="T_e44b1_level0_row9" class="row_heading level0 row9" >Golf ball</th>
#       <td id="T_e44b1_row9_col0" class="data row9 col0" >551</td>
#       <td id="T_e44b1_row9_col1" class="data row9 col1" >513</td>
#       <td id="T_e44b1_row9_col2" class="data row9 col2" >38</td>
#     </tr>
#   </tbody>
# </table>
